# %% [markdown]
# # SED MCMC Fitting Lite

# %% [markdown]
# This notebook is to explore the degeneracy between inclination $i$ and accretion rate $\dot{M}$. Started 2 August 2019.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy import integrate
import emcee
import corner
import time
# %matplotlib inline

# %%
G = 6.67259e-8
SIG_SB = 5.67051e-5
M_SUN = 1.99e33
R_SUN = 6.96e10
L_SUN = 3.839e33
h_PLANCK = 6.6260755e-27
c_LIGHT = 2.99792458e10
k_BOLTZ = 1.380658e-16

# %% [markdown]
# ### Temperature profile functions

# %%
def tempKepDisk(r, r_inner, m_dot, m_star):
    term1 = 3*G*m_star*m_dot / (8 * np.pi * SIG_SB * (r**3))
    term2 = (1 - (r_inner/r)**(1/2))
    return (term1 * term2)**(1/4)

def tempKepDiskNeg(r, r_inner, m_dot, m_star):
    return -tempKepDisk(r, r_inner, m_dot, m_star)

def findMaxTemp(r_inner, m_dot, m_star):
    res = minimize(tempKepDiskNeg, 2*r_inner, args=(r_inner, m_dot, m_star), method='Nelder-Mead')
    return (res.x[0], -res.fun)

def tempFUOriDisk(r, r_inner, m_dot, m_star):
    # Doesn't read in as arrays for some reason,
    # doing this element-wise...
    res = np.zeros(len(r))
    for i in range(len(r)):
        if r[i] <= findMaxTemp(r_inner, m_dot, m_star)[0]:
            res[i] = findMaxTemp(r_inner, m_dot, m_star)[1]
        else:
            res[i] = tempKepDisk(r[i], r_inner, m_dot, m_star)
    return res

# %% [markdown]
# ### Annuli Generators

# %%
def generateDistArrays(r_inner, r_outer, r_sep):
    r_list = np.arange(r_inner, r_outer, r_sep)
    r_tup = []
    for i in range(len(r_list)-1):
        r_tup.append((r_list[i], r_list[i+1]))
    r_tup = np.array(r_tup)
    r_b = np.array([i[1] for i in r_tup])
    r_a = np.array([i[0] for i in r_tup])
    r_avg = np.mean(r_tup, axis=1)
    return (r_tup, r_avg, r_a, r_b)

# %% [markdown]
# ### Luminosity functions

# %%
def lumWaveAnnulus(wavelength, temp, r_b, r_a):
    term1 = 2*np.pi *(r_b**2 - r_a**2)
    term2 = 2*h_PLANCK*(c_LIGHT**2)*(wavelength**(-5))*np.pi
    term3 = (np.exp(h_PLANCK*c_LIGHT/(wavelength*k_BOLTZ*temp))-1)**(-1)
    return term1*term2*term3

def lumFreqAnnulus(freq, temp, r_b, r_a):
    term1 = 2*np.pi *(r_b**2 - r_a**2)
    term2 = 2*h_PLANCK*(c_LIGHT**(-2))*(freq**3)*np.pi
    term3 = (np.exp(h_PLANCK*freq/(k_BOLTZ*temp))-1)**(-1)
    return term1*term2*term3

# %% [markdown]
# ### Class structure

# %%
class FUOri:

    # Initializer / Instance Attributes
    def __init__(self, r_star, r_inner, r_outer, m_star, m_dot):
        self.r_star = r_star
        self.r_inner = r_inner
        self.r_outer= r_outer
        self.m_star = m_star
        self.m_dot = m_dot
        
        # Distance arrays
        self.distances = 0
        
        # KHH88 "true vales"
        self.true_rad = 0
        self.true_temp = 0
        self.true_fluxes = 0

    # instance methods
    
    # Setting the distance arrays, DO THIS FIRST!
    def makeDistArrays(self, r_sep):
        self.distances = generateDistArrays(self.r_inner, self.r_outer, r_sep)
        
    def makeListDistArrays(self, points):
        self.distances = generateListDistArrays(points)
    
    # T(r) of each annulus
    def getTemperature(self):
        r = self.distances[1]
        return tempFUOriDisk(r, self.r_inner, self.m_dot, self.m_star)

    # Luminosity contribution of each annulus
    def getLuminosityWave(self, wave):
        r_tup, r_avg, r_a, r_b = self.distances
        temps = self.getTemperature()
        return lumWaveAnnulus(wave, temps, r_b, r_a)
    
    # Model spectrum
    def getModelSpectrumWave(self, wave_lower, wave_upper, binning):
        r_tup, r_avg, r_a, r_b = self.distances
        waves = np.arange(wave_lower, wave_upper+binning, binning)
        temp = tempFUOriDisk([r_avg[0]], self.r_inner, self.m_dot, self.m_star)
        lum = lumWaveAnnulus(waves, temp, r_b[0], r_a[0])
        for i in range(1,len(r_avg)):
            temp = tempFUOriDisk([r_avg[i]], self.r_inner, self.m_dot, self.m_star)
            lum += lumWaveAnnulus(waves, temp, r_b[i], r_a[i])
        return (waves,lum)
    
    def getModelSpectrumWavePoint(self, wave):
        r_tup, r_avg, r_a, r_b = self.distances

        temp = tempFUOriDisk([r_avg[0]], self.r_inner, self.m_dot, self.m_star)
        lum = lumWaveAnnulus(wave, temp, r_b[0], r_a[0])
        for i in range(1,len(r_avg)):
            temp = tempFUOriDisk([r_avg[i]], self.r_inner, self.m_dot, self.m_star)
            lum += lumWaveAnnulus(wave, temp, r_b[i], r_a[i])
        return lum
    
    # Total luminosity
    def getTotalLuminosity(self):
        r_tup, r_avg, r_a, r_b = self.distances
        lumTot = 0
        for i in range(len(r_avg)):
            temp = tempFUOriDisk([r_avg[i]], self.r_inner, self.m_dot, self.m_star)
            lumTot += 2*np.pi*(r_b[i]**2 - r_a[i]**2)*SIG_SB*temp**4
        return lumTot[0]

# %% [markdown]
# ### Making an instance of the class

# %%
M_STAR = 0.95*M_SUN
R_STAR= 0.96*R_SUN
R_OUTER = 300 * R_STAR
ACC_RATE = (10**-0.58) * 1e-6 * M_SUN / 3.154e7


INC = 60.

# %%
gaia17bpi = FUOri(R_STAR, R_STAR, R_OUTER, M_STAR , ACC_RATE)

# Equal spacing of annuli
gaia17bpi.makeDistArrays(3*R_STAR)

# %%
modSpec = gaia17bpi.getModelSpectrumWave(0.1*1e-4, 1000*1e-4, 1e-6)

# %%
PATH = 'C:/Users/tonyc/OneDrive/Documents/2019 Summer/Papers/Gaia 17bpi/'

DIST = 1.27e3*3.08567758128e18

# %% [markdown]
# ### Reading in data points

# %%
log_lam_OPT = np.array([-0.41337227, -0.36337227, -0.31337227, -0.26337227, -0.21337227,
        -0.16337227, -0.11337227, -0.06337227, -0.01337227,  0.03662773,
         0.08662773,  0.13662773,  0.18662773,  0.23662773,  0.28662773,
         0.33662773])
log_lam_F_OPT = np.array([-12.92964718, -12.52247425, -12.18216577, -11.8971224 ,
        -11.6573574 , -11.45449663, -11.28177854, -11.13405422,
        -11.00778731, -10.9010541 , -10.81354345, -10.74655683,
        -10.70300832, -10.68742459, -10.70594491, -10.76632117])
log_lam_F_OPT_ERR = -0.02*log_lam_F_OPT

# %%
10**log_lam_OPT
# Out:
# array([0.38603593, 0.43313944, 0.48599044, 0.54529025, 0.61182572,
#        0.68647975, 0.77024295, 0.8642268 , 0.96967842, 1.08799708,
#        1.2207528 , 1.36970717, 1.53683672, 1.72435917, 1.93476281,
#        2.17083957])

# %% [markdown]
# ### Implementing extinction

# %% [markdown]
# Funcational form taken from Cardelli, Clayton, and Mathis (1989). Using the ISM average of $R \approx 3.1$.

# %%
def calcExtinction(x, r):
    if 0. <= x <= 1.1:
        return 0.574*(x**1.61) - (0.527*(x**1.61))/r
    elif 1.1 < x <= 3.3:
        y = x - 1.82
        return 1 + 0.17699*y - 0.50447*(y**2) - 0.02427*(y**3) + 0.72085*(y**4) \
        + 0.01979*(y**5) - 0.77530*(y**6) + 0.32999*(y**7)\
        +(1.41338*y + 2.28305*(y**2) + 1.07233*(y**3) - 5.38434*(y**4)\
        - 0.62251*(y**5) + 5.30260*(y**6) - 2.09002*(y**7) )/r
    elif 3.3 < x <= 8:
        if 5.9 <= x <= 8:
            f_a = -0.04473*(x - 5.9)**2 - 0.009779*(x - 5.9)**3
            f_b = 0.2130*(x - 5.9)**2 + 0.1207*(x - 5.9)**3
        else:
            f_a = 0
            f_b = 0
        return 1.752 - 0.316*x - 0.104/((x - 4.67)**2 + 0.341) \
                + f_a + (-3.090 + 1.825*x + 1.206/((x - 4.62)**2 + 0.263) + f_b)/r
    else:
        return 0

# %%
def makeExtinctionCurve(waves, r):    
    waves_mod = 1/(waves*1e-4)
    return waves, np.array([calcExtinction(wave, r) for wave in waves_mod])

# %%
wav, lum = modSpec
a_lambda = 3*makeExtinctionCurve(wav*1e8, 3.1)[1]

# %%
flux = np.cos(np.radians(INC))*lum/(2*np.pi*DIST**2)
flux_corrected = flux*(10**(-a_lambda/2.5))

# %% [markdown]
# ### Plotting data with model

# %%
fig=plt.figure(figsize=(6, 6), dpi= 80)
plt.rcParams.update({'font.size': 14})
plt.plot(np.log10(wav*1e4), np.log10(np.cos(np.radians(INC))*wav*lum/(2*np.pi*DIST**2)), \
         'k--', alpha=0.5, label='Blackbody Disk Model')
plt.plot(np.log10(wav*1e4), np.log10(flux_corrected*wav), \
         'k-', label='Extinction Corrected')
plt.errorbar(log_lam_OPT, log_lam_F_OPT, yerr=log_lam_F_OPT_ERR, marker='o', \
             linestyle='', color='c',label='Optical photometry')
plt.xlabel(r'log $\lambda$ ($\mu$m)')
plt.ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$')
plt.title('Gaia 17bpi: SED Comparison')
plt.ylim(-15, -10)
plt.xlim(-0.8, 1.8)
plt.legend()
plt.show()

# %% [markdown]
# ## MCMC Routine

# %%
def lnlike(theta, x, y, yerr):
    m_dot, inc = theta
    
    m_dot = 10**m_dot
    inc = np.degrees(np.arccos(inc))
    
    m_dot = m_dot* 1e-6 * M_SUN / 3.154e7
    
    gaia17bpi = FUOri(R_STAR, R_STAR, 100*R_SUN, M_STAR, m_dot)
    gaia17bpi.makeDistArrays(3*R_STAR)
    # Converting?
    x = (10**x)*1e-4
    modSpec = gaia17bpi.getModelSpectrumWavePoint(x)
    a_lambda = 3*makeExtinctionCurve(x*1e8, 3.1)[1]
    flux = np.cos(np.radians(inc))*modSpec/(2*np.pi*DIST**2)
    flux_corrected = flux*(10**(-a_lambda/2.5))
    model = np.log10(x*flux_corrected)
    inv_sig = 1/yerr
    return np.sum(np.log((1/np.sqrt(2*np.pi))*inv_sig) - 0.5*((y - model)*inv_sig)**2)

# %% [markdown]
# Setting ranges of uniform priors

# %%
M_DOT_LOW = -2.5
M_DOT_HIGH = 2.5
INC_LOW = 0.05
INC_HIGH = 0.95

# %%
def lnprior(theta):
    m_dot, inc = theta
    if M_DOT_LOW  < m_dot < M_DOT_HIGH \
    and INC_LOW < inc < INC_HIGH:
        return 0.0
    return -np.inf

# %%
def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return (lp + lnlike(theta, x, y, yerr))

# %%
ndim, nwalkers = 2, 8

m_dot_start = -0.5
inc_start = 0.5
start = np.array((m_dot_start, inc_start))
pos = [start + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]

# %%
x = log_lam_OPT
y_meas = log_lam_F_OPT
y_err = log_lam_F_OPT_ERR

# %%
lnprob((m_dot_start, inc_start), x,y_meas,y_err)
# Out:
# 5.819643082274849

# %%
280.5/60
# Out:
# 4.675

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x, y_meas, y_err))
# %time sampler.run_mcmc(pos, 300)
# Out:
# Wall time: 4min 55s
# (array([[-0.4508124 ,  0.28271564],
#         [-0.22486371,  0.27563512],
#         [-0.27211038,  0.16686054],
#         [-0.48399762,  0.32795206],
#         [-0.41464714,  0.31892866],
#         [-0.46428526,  0.32993246],
#         [-0.65893573,  0.62926273],
#         [-0.36326009,  0.24071858]]),
#  array([8.45786834, 2.42967046, 7.01074525, 8.80089561, 8.53085157,
#         8.89005766, 7.75966196, 8.5352538 ]),
#  ('MT19937', array([2510674280, 4103933833, 3999236366, 3059245110, 1371874765,
#          4289561119, 1425682303, 2766940559, 3850622346, 3183125300,
#          1424651020, 3544958512, 4197095271,   81422796, 1008027120,
#           510641468, 1414697570, 4009540069, 3304100241, 2781257345,
#          4247174277, 1858018639, 3379109257, 1865131158, 2183121218,
#          1928774497, 3361030322, 3601364330, 1384537507, 4206379285,
#          1217986601, 1730793145,  931335749, 4124282460, 4169983860,
#          2742992910, 2892745153, 2698364038, 2758547400, 2309346011,
#          1445800014,  478432053, 1436347465, 3116204372, 3120382233,
#          1801199174,  985061337,  370305765, 3807634219, 3727731299,
#          1128747713, 3167876666, 3555335903, 1929237288, 2129583814,
#          2080559136, 2727934325,  639182963, 1244046349, 1684173920,
#           553876319,  197253971, 1850842758, 2454118109, 3653694492,
#          3831526990, 2337928346, 2770046895,  142325390,  248479544,
#          1179729582, 2575433881,  337761338,  790015627,  203585020,
#          1067028579, 2324369194, 4012461088, 3551435157, 2707723787,
#          2033352517, 2231403800, 3733768099, 3145162965,  101018640,
#          3715107303, 1353209312,  126511620,  869281298, 2524502165,
#          2700557132, 3141639202, 1010272786, 3672290384, 4249286588,
#          1695987928, 1696703920, 2549541532, 1369535046, 3719859328,
#          2606815834, 4081150067, 1087135947, 4275217886, 1283439451,
#           680825032,  456457153,   36012118, 3998550372,  871294010,
#          3827660941,  974643608,  656486958, 2698207571, 3446276729,
#          3055690656,  993577706,  700747772, 3707633172, 1801377063,
#          3307091194, 3844248323,  261936983, 1392285769, 1859354579,
#          2631938262, 3781178415,  287522278, 1876243141, 3727282068,
#          3948083362, 1856008911, 3189787576,  821395294, 4072818181,
#          1534645072, 2915255073, 1491481313,  787058135, 2077536097,
#          3684701771, 1323132621,  366864879,   60110859, 3843974411,
#          2191277440,   93785077, 1790949820, 2591318973,  203699026,
#           215787322, 1157688904, 4169209080, 3719917561, 2974591872,
#          3903941852, 2595002475,  444909301, 3418175511, 1758818803,
#          1456167694, 3660491523, 3583981900,  115726776, 2770178287,
#          3685629696,  806866870, 3845329738,  713259844, 4156545897,
#          2024977880, 3264073497, 1111994311, 4036904403, 2476400183,
#           161409844,  125956676, 4233383271, 1891359345, 3038132711,
#           570299456,  650820560, 1833307700, 3681130521, 1927462399,
#           943732359, 3103389325, 4061532392, 3004875898, 1752037626,
#          1306262291,  596283938,  214525798, 1320376750, 4150554945,
#           505673242, 3362885441, 1797629790, 1382747117, 2887446322,
#          1069001899, 2950106510, 1403029481, 3765365102, 1497964185,
#          3797292079, 2999331231,  738584822, 2626232224, 1905230826,
#          3910560026, 1272566902,  924018250, 1437593359, 3351046489,
#          3537546392, 3559348932, 1252635377, 1664731184, 3210753808,
#          1122984867, 2862233130, 4261346210, 2220554880,   48266479,
#          2937237720, 2114397396,  768995102, 3655368176,  843870521,
#           827893845,  388201298,  592700589, 2690626056,  842301348,
#          2370613179, 4255746928, 2539110317,  561340315,  160653130,
#          2405314025, 3344548326,  652262278, 3587592241, 2929142372,
#          3302974902,  370226193,  692216471, 3142182645, 2369957536,
#          3725004927,  978097801, 3811621446, 2427821785, 3711948951,
#           686453354, 1606866415, 3456684549,  278591200,  105342175,
#          4245345805, 1442202301,  607263978, 1165215014, 2766388806,
#          2375023134, 3448362428, 4052041334, 1269268363, 3135694148,
#           987776830, 3180612757, 1583406799, 2638608977, 2581827468,
#          1421029345,  552645492, 3992941789,  440134675, 1102518698,
#           742742765,  204096437, 3827827704, 4181196379, 3871692052,
#          1645762823, 1343748979,  479194584, 2320818668, 3078893240,
#          2277839492,  857736869,  101537855,  523705145,  619502087,
#          1036959246,  960449039,  716848116, 3209016769,  134023634,
#          1890851542, 1231339939, 1045542147, 4116487580, 1770844380,
#           673776823, 3429603080, 1152426753, 2240240001, 1803077951,
#          1187730183, 3740448851, 3127154557, 2474848229, 2478232201,
#           641756454,  547174274, 4273735149, 4169122992,  333912053,
#          2901818669, 2989416362, 1190780395, 3669947449, 1946117567,
#           821381103, 1224067673, 2163187183, 3142693890, 3265595510,
#          1876900520, 1119287310, 3274082064, 3699169727,  778532651,
#          3535922360,  825364397, 3861277386,   21887566, 1818978262,
#          3375169903, 3095444398,  268321812,  830397901,  141487445,
#          4069048883, 4115926495, 2156397080, 2455814790,  515231397,
#          2394376258, 4109955843, 4150193017, 3213265693, 2074170372,
#          4234586976, 1209144629, 3421234708, 2303028346, 3164012239,
#          1124920825, 2335781312, 4206108843, 2458184862, 2519406630,
#          2789231735, 3401848810, 1452531963, 1863996730, 1131551419,
#          3084083265, 3778315698, 2027958186,  234516564, 3532364076,
#          3347790565,   63504958,   64635449, 2230960994, 4243623593,
#          1830285919,   12475117, 3734372729, 2860555264, 1826413115,
#           295069896, 2430717054, 1307574127, 3063482366, 4223351515,
#          1083425179, 1778557201, 3749254878,  351471153,  416914020,
#          2048391842, 3327411501, 1613068666, 1307313895, 2968692721,
#          2168447007,  982497165, 1752842529,  188575250,  158011583,
#          3653959726, 2323156241,  159353746, 1552851594, 2985238761,
#          2519171976,  294570848, 1494185384,  465626192, 3640531449,
#           208393740,  697142469, 3778190919, 2718083713, 2186104494,
#            26466955, 2060066763, 2254076400, 4158175808, 3869734428,
#          3927074414, 3710406433, 2304040112, 2394827181, 2761125424,
#           604025451, 2405751391, 3033663489, 1213340391, 2820755866,
#          1312747572,  528754483, 1323764188, 1967966082, 2253848423,
#          1794269110, 1588070161, 3427254580, 3652814362,  624471398,
#           398912516, 3828295208, 3025921315, 3606121266, 2419114691,
#          2079765593,  119025081,  364542048, 2017327581, 3390383699,
#          3715395774, 2962385211, 3216284772, 2342257274, 3391666086,
#          3168666160, 3318905452, 3924473366, 2642957661,  671174492,
#          3237309766, 2243139842,   99788972, 3140273527, 3255016937,
#          2114872246, 2290684929,  852633689, 1115000953,  457958259,
#          3977264493,  694145358,  815137347,  797537219, 2631205100,
#           177657300,  724426027, 2239709483, 1515259109, 4154183418,
#          3911089437,  344270378, 3209817083, 4206663042, 2194635673,
#          1443766958,  180056065,  141486707, 1782178439, 2414560422,
#           151420809,  798844702, 4195798146, 1855681463, 2686751143,
#            19158854, 4276776022, 3035499293, 1810348881,  925500160,
#          2676514418, 2791422326, 3769710894, 3710569191, 3807594341,
#          3722443240, 1547344389, 3439321582, 1871734288, 2338530530,
#          4121603088,  842246009, 3070488708, 2886595526, 1488062287,
#          2121969307, 3640849784, 2230109841, 2798460703, 2671023485,
#          1183000578, 2611628496, 2186735248, 3042879039,  261323555,
#          2114964526, 4177534355, 2071761207,  988500445, 3297207035,
#           481343061,  551532167, 2917347781, 3124013681, 3642794368,
#           478241137, 3478785453, 2956260298,  111075678, 1161886506,
#          2227249857, 3184038302, 2771873301, 3408990879, 1932870908,
#          4002579364, 3229241405, 2421717962,  916304787, 4224315801,
#          3771265652, 2349937276, 4261969062,  584810955, 3172828690,
#          1819958918, 3814897956,   57636620, 4004377142,   93027813,
#          2265543131,   96298012, 3376704438,  338124582, 1089584569,
#          2100768259, 3948275526, 3327065207, 3032011976, 4248089936,
#           164190935, 3919391064, 1697816842, 2730263986, 3599244315,
#          3919733151,  740900834, 1761158101, 1096743311,   15734239,
#          3532602798,  385602815, 1809659801,  789837152, 3160414408,
#           965594998, 2434776000, 1507067349,  551445244,    2143818,
#          1649195911, 4051032137, 3273207468, 2141682799,  892223465,
#          4035831336, 1746457062, 1753665299, 3135357321,  561776648,
#          2992364251, 2233963266, 1793011612, 3995288163, 3465891946,
#          1813957796, 3516671626, 3465863524,  958384472, 1865343746,
#          1801082656, 1833650356, 1500021779,  885660278, 3524132133,
#          1120616273, 1590620140,  864951061, 2357635481], dtype=uint32), 144, 0, 0.0))

# %%
samples = sampler.chain[:, 150:, :].reshape((-1, ndim))
fig = plt.figure(figsize=(10,6))
plt.plot(samples)
plt.xlabel('Step number up to 1000 total steps')
plt.ylabel('Estimated values of parameters')
plt.title('Evolution in estimated values using MCMC')
plt.xticks([])
plt.show()

# %%
median_calcuated = np.median(samples, axis=0)

fig = corner.corner(samples, labels=[r'$\log\dot{M}$', r'$\cos\; i$'], verbose=True,
                       quantiles=(0.16, 0.5,0.84), plot_contours=True, scale_hist=True,
                       show_titles=True, title_kwargs={"fontsize": 12})

axes = np.array(fig.axes).reshape((ndim, ndim))

for i in range(ndim):
    ax = axes[i, i]
    ax.axvline(median_calcuated[i], color="r")
    
for yi in range(ndim):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(median_calcuated[xi], color="r")
        ax.axhline(median_calcuated[yi], color="r")
        ax.plot(median_calcuated[xi], median_calcuated[yi], "sr")

fig.show()
# fig.savefig("mdot_i_degeneracy.png")
# Out:
# Quantiles:
# [(0.16, -0.6487200062321745), (0.5, -0.5118234698585608), (0.84, -0.327025405366355)]
# Quantiles:
# [(0.16, 0.22154688996245508), (0.5, 0.36754579824073597), (0.84, 0.5423561193824269)]
