# %% [markdown]
# # SED Constraint on Temperature Profile

# %% [markdown]
# Started 31 March 2020. The goal of this is to create a covariance plot demonstrating how $A_V$ trades off with the power law governing the innermost parts of the disk. Can I do this in less than a month??

# %% [markdown]
# ### Imports

# %%
import numpy as np
from scipy import optimize
from scipy import interpolate
from scipy import integrate
from astropy.convolution import convolve, convolve_fft
import matplotlib.pyplot as plt
from fu_ori_functions_oct29_copy import *
from fu_ori_classes_oct29_copy import *
import matplotlib.gridspec as gridspec
from PyAstronomy import pyasl
import scipy.signal as signal


import emcee
import corner
import time
# %matplotlib inline

# %%
G = 6.67259e-8
SIG_SB = 5.67051e-5
M_SUN = 1.99e33
R_SUN = 6.96e10
L_SUN = 3.839e33
h_PLANCK = 6.6260755e-27
c_LIGHT = 2.99792458e10
k_BOLTZ = 1.380658e-16

# %%
ATM_TABLE = dict()
ATMOS_FACTOR = 100

# %%
def getDataArrayMOD(data_file):
    txt = open(data_file)
    fulltxt = txt.readlines()
    # Cleaning lines
    newtxt = []
    for i in range(0,len(fulltxt), 2):
        line = fulltxt[i][:-1]
        line = line.split()
        if line[0] == '#':
            line = [line[1], line[2]]
        newtxt.append(line)
    # Casting as floats
    newtxt = np.array(newtxt).astype(np.float64)
    return newtxt

# %%
def direcToArray(directory):
    for temp in range(2000, 10000+ATMOS_FACTOR, ATMOS_FACTOR):
        for grav in [1.5, 4.0]:
            try:
                atmos_file = directory + 'pr.lte' + str(int(temp/ATMOS_FACTOR)) \
                        + '-' + str(grav) + '-0.0.spec'
                txt = open(atmos_file)
                fulltxt = txt.readlines()
                # Cleaning lines
                newtxt = []
                for i in range(len(fulltxt)):
                    line = fulltxt[i][:-1]
                    line = line.split()
                    newtxt.append(line)
        
                # Casting as floats
                newtxt = np.array(newtxt).astype(np.float64)
                
                # Choosing which model to use
                wav, lum = newtxt[:,0], newtxt[:,1]
                ATM_TABLE[(temp, grav)] = np.array([wav, lum])
            except:
                print('No atmosphere found for temp = ' + str(temp) + \
                      ' grav = ' + str(grav))

# %%
direcToArray('/Users/tonyrodriguez/Documents/Docs/2019 Summer/Stellar Atmospheres/')
# Out:
# No atmosphere found for temp = 7100 grav = 1.5
# No atmosphere found for temp = 7100 grav = 4.0
# No atmosphere found for temp = 7300 grav = 1.5
# No atmosphere found for temp = 7300 grav = 4.0
# No atmosphere found for temp = 7500 grav = 1.5
# No atmosphere found for temp = 7500 grav = 4.0
# No atmosphere found for temp = 7700 grav = 1.5
# No atmosphere found for temp = 7700 grav = 4.0
# No atmosphere found for temp = 7900 grav = 1.5
# No atmosphere found for temp = 7900 grav = 4.0
# No atmosphere found for temp = 8100 grav = 1.5
# No atmosphere found for temp = 8100 grav = 4.0
# No atmosphere found for temp = 8300 grav = 1.5
# No atmosphere found for temp = 8300 grav = 4.0
# No atmosphere found for temp = 8500 grav = 1.5
# No atmosphere found for temp = 8500 grav = 4.0
# No atmosphere found for temp = 8700 grav = 1.5
# No atmosphere found for temp = 8700 grav = 4.0
# No atmosphere found for temp = 8900 grav = 1.5
# No atmosphere found for temp = 8900 grav = 4.0
# No atmosphere found for temp = 9100 grav = 1.5
# No atmosphere found for temp = 9100 grav = 4.0
# No atmosphere found for temp = 9300 grav = 1.5
# No atmosphere found for temp = 9300 grav = 4.0
# No atmosphere found for temp = 9500 grav = 1.5
# No atmosphere found for temp = 9500 grav = 4.0
# No atmosphere found for temp = 9700 grav = 1.5
# No atmosphere found for temp = 9700 grav = 4.0
# No atmosphere found for temp = 9900 grav = 1.5
# No atmosphere found for temp = 9900 grav = 4.0
# No atmosphere found for temp = 10000 grav = 1.5

# %% [markdown]
# ### Interpolating grid of stellar atmospheres on same grid as data:

# %% [markdown]
# First, reading in data...

# %%
txt_in = getDataArrayMOD('hbc_out_new_calib.csv')
WAV_DAT = txt_in[:,0]
FLUX_DAT = txt_in[:,1]
FLUX_DAT_ERR = -0.01*FLUX_DAT

# %%
txt_in2 = getDataArrayMOD('hbc_out_new_calib_NEW_NIR.csv')
WAV_DAT2 = txt_in2[:,0]
FLUX_DAT2 = txt_in2[:,1]
FLUX_DAT_ERR2 = -0.01*FLUX_DAT2

# %%
import spectres

# %%
def getInterpTable(st_atm_table, waves_data):
    out_table = dict()
    for key in ATM_TABLE:
        wav, lum = ATM_TABLE[key]
#         interp_func = interpolate.interp1d(wav, lum, kind = 'linear')
#         out_table[key] = waves_data, interp_func(waves_data)
        out_table[key] =  waves_data, spectres.spectres(waves_data, wav, lum)
    return out_table

# %%
WAVES_DATA_LOGGED = WAV_DAT

# %%
len(WAVES_DATA_LOGGED)
# Out:
# 435

# %%
np.logspace(np.log10(4000),np.log10(24100), 10)
# Out:
# array([ 4000.        ,  4883.39535656,  5961.88755213,  7278.56349711,
#         8886.02579606, 10848.4942777 , 13244.37164535, 16169.37574839,
#        19740.36361205, 24100.        ])

# %%
WAVES_DATA = 1e4*(10**WAVES_DATA_LOGGED)
# WAVES_DATA = np.logspace(np.log10(4000),np.log10(24100), 800)

# %%
ATM_TABLE_INTERP = getInterpTable(ATM_TABLE, WAVES_DATA)

# %%
ATM_TABLE_INTERP.keys()
# Out:
# dict_keys([(2000, 1.5), (2000, 4.0), (2100, 1.5), (2100, 4.0), (2200, 1.5), (2200, 4.0), (2300, 1.5), (2300, 4.0), (2400, 1.5), (2400, 4.0), (2500, 1.5), (2500, 4.0), (2600, 1.5), (2600, 4.0), (2700, 1.5), (2700, 4.0), (2800, 1.5), (2800, 4.0), (2900, 1.5), (2900, 4.0), (3000, 1.5), (3000, 4.0), (3100, 1.5), (3100, 4.0), (3200, 1.5), (3200, 4.0), (3300, 1.5), (3300, 4.0), (3400, 1.5), (3400, 4.0), (3500, 1.5), (3500, 4.0), (3600, 1.5), (3600, 4.0), (3700, 1.5), (3700, 4.0), (3800, 1.5), (3800, 4.0), (3900, 1.5), (3900, 4.0), (4000, 1.5), (4000, 4.0), (4100, 1.5), (4100, 4.0), (4200, 1.5), (4200, 4.0), (4300, 1.5), (4300, 4.0), (4400, 1.5), (4400, 4.0), (4500, 1.5), (4500, 4.0), (4600, 1.5), (4600, 4.0), (4700, 1.5), (4700, 4.0), (4800, 1.5), (4800, 4.0), (4900, 1.5), (4900, 4.0), (5000, 1.5), (5000, 4.0), (5100, 1.5), (5100, 4.0), (5200, 1.5), (5200, 4.0), (5300, 1.5), (5300, 4.0), (5400, 1.5), (5400, 4.0), (5500, 1.5), (5500, 4.0), (5600, 1.5), (5600, 4.0), (5700, 1.5), (5700, 4.0), (5800, 1.5), (5800, 4.0), (5900, 1.5), (5900, 4.0), (6000, 1.5), (6000, 4.0), (6100, 1.5), (6100, 4.0), (6200, 1.5), (6200, 4.0), (6300, 1.5), (6300, 4.0), (6400, 1.5), (6400, 4.0), (6500, 1.5), (6500, 4.0), (6600, 1.5), (6600, 4.0), (6700, 1.5), (6700, 4.0), (6800, 1.5), (6800, 4.0), (6900, 1.5), (6900, 4.0), (7000, 1.5), (7000, 4.0), (7200, 1.5), (7200, 4.0), (7400, 1.5), (7400, 4.0), (7600, 1.5), (7600, 4.0), (7800, 1.5), (7800, 4.0), (8000, 1.5), (8000, 4.0), (8200, 1.5), (8200, 4.0), (8400, 1.5), (8400, 4.0), (8600, 1.5), (8600, 4.0), (8800, 1.5), (8800, 4.0), (9000, 1.5), (9000, 4.0), (9200, 1.5), (9200, 4.0), (9400, 1.5), (9400, 4.0), (9600, 1.5), (9600, 4.0), (9800, 1.5), (9800, 4.0), (10000, 4.0)])

# %%
class FUOriEnvironment:
    
    # Initializer / Instance Attributes
    def __init__(self, wave_lower_SED, wave_upper_SED):
        
        self.wave_lower_SED = wave_lower_SED
        self.wave_upper_SED = wave_upper_SED
        
        # Storing classes
        self.fuori = []
        
    # instance methods
    
    # Creating FU Ori object as accretion disk
    def createFUOri(self, r_star, r_outer, m_star, m_dot, inc, dist, grav, direc, a_v, atm_table, pl_index):
        fuori = FUOri(r_star, r_star, r_outer, m_star, m_dot, np.radians(inc), a_v, atm_table, pl_index)
        fuori.setAnnuliValues(10000, 2000, 200, 2*R_STAR)
        fuori.createAnnuliFromDirec(grav, direc, 'stellar atmospheres')
        fuori.createModelSpectrum('stellar atmospheres', False)
        self.fuori.append(fuori)

# %% [markdown]
# ### Making an instance of the class

# %%
PARAMS = [0.56, 1.39, -5.41, 3.16, 30, 0]
PARAMS_2 = [0.56, 1.39,  -4.82, 4.8, 30, 0]
PARAMS_3 = [0.56, 1.39, -6, 1., 30, 0]

# %%
M_STAR = PARAMS[0]*M_SUN
R_STAR = PARAMS[1]*R_SUN
R_OUTER = 100*R_SUN
M_DOT = (10**PARAMS[2]) * M_SUN / 3.154e7
A_V = PARAMS[3]
INC =PARAMS[4]
DIST = 795*3.08567758128e18
DIREC = '/Users/tonyrodriguez/Documents/Docs/2019 Summer/Stellar Atmospheres/'

# %%
# %time gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
# %time gaia17bpi_env.createFUOri(r_star = PARAMS[1]*R_SUN, r_outer = R_OUTER, m_star = PARAMS[0]*M_SUN,\
                          m_dot = (10**PARAMS[2]) * M_SUN / 3.154e7, inc = PARAMS[4],\
                                a_v = PARAMS[3],dist = DIST, grav = 1.5, \
                                direc = DIREC, pl_index = 0, atm_table=ATM_TABLE_INTERP)
# %time gaia17bpi_env.createFUOri(r_star = PARAMS_2[1]*R_SUN, r_outer = R_OUTER, m_star = PARAMS_2[0]*M_SUN,\
                          m_dot = (10**PARAMS_2[2]) * M_SUN / 3.154e7, inc = PARAMS_2[4],\
                                a_v = PARAMS_2[3],dist = DIST, grav = 1.5, \
                                direc = DIREC, pl_index = PARAMS_2[5], atm_table=ATM_TABLE_INTERP)
# %time gaia17bpi_env.createFUOri(r_star = PARAMS_3[1]*R_SUN, r_outer = R_OUTER, m_star = PARAMS_3[0]*M_SUN,\
                          m_dot = (10**PARAMS_3[2]) * M_SUN / 3.154e7, inc = PARAMS_3[4],\
                                a_v = PARAMS_3[3],dist = DIST, grav = 1.5, \
                                direc = DIREC, pl_index = PARAMS_3[5], atm_table=ATM_TABLE_INTERP)
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 7.39 µs
# CPU times: user 3.59 ms, sys: 200 µs, total: 3.79 ms
# Wall time: 3.68 ms
# CPU times: user 3.84 ms, sys: 170 µs, total: 4.01 ms
# Wall time: 3.92 ms
# CPU times: user 3.34 ms, sys: 329 µs, total: 3.67 ms
# Wall time: 3.44 ms

# %%
gaia17bpi_env.fuori[0].temps[0]
# Out:
# 7000.0

# %%
gaia17bpi_env.fuori[0].getTotalLum()/L_SUN
# Out:
# 24.112080614468898

# %% [markdown]
# ### Quick minimization routine

# %%
def getLstSqrs(theta):
    m_dot = theta
    
    r_star = 1.39
    m_star = r_star/2
    r_star = r_star*R_SUN
    m_dot = 10**(m_dot)
    m_star = m_star*M_SUN
    inc = 30
    m_dot = m_dot* M_SUN / 3.154e7
    a_v = 3.16

    gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
    try:
        gaia17bpi_env.createFUOri(r_star = r_star, r_outer = R_OUTER, m_star = m_star,\
                          m_dot = m_dot, inc = inc, a_v = a_v, dist = DIST, grav = 1.5, \
                              direc = DIREC, atm_table=ATM_TABLE_INTERP, pl_index=0)
    except:
        gaia17bpi_env.createFUOri(r_star = r_star*2, r_outer = R_OUTER, m_star = m_star,\
                          m_dot = m_dot, inc = inc, a_v = a_v, dist = DIST, grav = 1.5, \
                              direc = DIREC, atm_table=ATM_TABLE_INTERP, pl_index=0)

    x = WAV_DAT
    # Converting units to properly compare model to data
    x_new = (10**x)*1e4
    modSpec = np.zeros(len(x_new))
    modSpec = gaia17bpi_env.fuori[0].mod_spec_lums
    modSpec = pyasl.unred(x_new, modSpec, -a_v/3.1)
    flux = np.cos(np.radians(inc))*modSpec/(2*np.pi*DIST**2)

    model = np.log10(x_new*flux*1e-8)
    data = FLUX_DAT

    return np.sum((model - data)**2)

# %%
from scipy import optimize
x0 = [-5.4]
optimize.minimize(getLstSqrs, x0, method='Nelder-Mead', tol=1e-6)
# Out:
#  final_simplex: (array([[-5.50313793],
#        [-5.50313845]]), array([1.36700504, 1.36700504]))
#            fun: 1.3670050403155671
#        message: 'Optimization terminated successfully.'
#           nfev: 40
#            nit: 20
#         status: 0
#        success: True
#              x: array([-5.50313793])

# %%
gaia17bpi_env.fuori[0].temps[11]
# Out:
# 5000.0

# %%
wav, lum = gaia17bpi_env.fuori[0].mod_spec_waves, gaia17bpi_env.fuori[0].mod_spec_lums
wav1, lum1 = gaia17bpi_env.fuori[1].mod_spec_waves, gaia17bpi_env.fuori[1].mod_spec_lums
wav2, lum2 = gaia17bpi_env.fuori[2].mod_spec_waves, gaia17bpi_env.fuori[2].mod_spec_lums

wav3, lum3 = gaia17bpi_env.fuori[0].annuli[0].wavelengths, gaia17bpi_env.fuori[0].annuli[0].lums
wav4, lum4 = gaia17bpi_env.fuori[0].annuli[11].wavelengths, gaia17bpi_env.fuori[0].annuli[11].lums
wav5, lum5 = gaia17bpi_env.fuori[0].annuli[21].wavelengths, gaia17bpi_env.fuori[0].annuli[21].lums




lum = pyasl.unred(wav, lum, -PARAMS[3]/3.1)
lum1 = pyasl.unred(wav, lum1, -PARAMS_2[3]/3.1)
lum2 = pyasl.unred(wav, lum2, -PARAMS_3[3]/3.1)

lum3 = 5e22*pyasl.unred(wav3, lum3, -PARAMS[3]/3.1)
lum4 = 8e23*pyasl.unred(wav4, lum4, -PARAMS[3]/3.1)
lum5 = 0.3e22*pyasl.unred(wav5, lum5, -PARAMS[3]/3.1)

# %% [markdown]
# ### Plotting data with model

# %%
wav_mods = np.array([wav, wav1, wav2, wav3, wav4, wav5])
lum_mods = np.array([lum, lum1, lum2, lum3, lum4, lum5])

# %%
model_wav = np.log10(wav*1e-4)
model_wav_flux =  np.log10(lum*wav*1e-8*np.cos(np.radians(INC))/(2*np.pi*DIST**2))

# %%
b, a = signal.butter(1, 0.35, 'low', analog=False)
filtered_signal = signal.filtfilt(b, a,  model_wav_flux)

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
fl2 = spectres.spectres(WAV_DAT, WAV_DAT2, FLUX_DAT2)
# Out:
# Spectres: new_wavs contains values outside the range in spec_wavs, new_fluxes and new_errs will be filled with the value set in the 'fill' keyword argument.

# %%
fig=plt.figure(figsize=(6, 8), dpi= 100)
gs = gridspec.GridSpec(2, 1,height_ratios=[5, 1])
plt.rcParams.update({'font.size': 14})

ax = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])


# plt.errorbar(WAV_DAT, FLUX_DAT, yerr=FLUX_DAT_ERR, marker='o', \
#              linestyle='', color='r', alpha=1, label='Palomar + IRTF \nResampled Spectra')

ax.plot(WAV_DAT, FLUX_DAT, 'ro', markersize=1, alpha=1, label='Resampled Spectra')
ax.plot(WAV_DAT2, FLUX_DAT2, 'go', markersize=1, alpha=1, label='Resampled Spectra')


# ax.plot(model_wav,model_wav_flux, \
#          'ko', markersize = 1,  label='Stellar Atmospheres \n Acc. Disk (unsmoothed)')

ax.plot(model_wav, filtered_signal,'ko' , markersize = 1,  label='Stellar Atmospheres \n Acc. Disk (smoothed)')


# ax2.plot(model_wav, 100*(model_wav_flux - FLUX_DAT)/model_wav_flux, 'o', markersize=1)
# ax2.plot(model_wav, np.zeros(len(model_wav_flux)), 'k--')

ax2.plot(model_wav, np.zeros(len(model_wav_flux)), 'k-')
ax2.plot(model_wav, (1/0.4)*np.log10((10**filtered_signal)/(10**FLUX_DAT)), 'ro', markersize=1)
ax2.plot(model_wav, (1/0.4)*np.log10((10**filtered_signal)/(10**fl2)), 'go', markersize=1)





ax2.set_xlabel(r'log $\lambda$ ($\mu$m)')
ax2.set_ylabel(r'$\Delta$ m (mag)')
ax2.set_xlim(-0.5, 0.4)
ax2.set_ylim(-0.5,0.5)


ax2.set_xlabel(r'log $\lambda$ ($\mu$m)')
ax.set_ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$')
# ax2.set_ylabel(r'Percent Error')

ax.set_title('HBC 722 SED: Model vs. Data')
# ax.set_ylim(-12.5, -8.7)

ax.set_xlim(-0.42, 0.4)
ax2.set_xlim(-0.42, 0.4)

legend_elements = [Line2D([0], [0], color='r', lw=2, label='Resampled Spectra (NIR: TripleSpec)'),
                   Line2D([0], [0], color='g', lw=2, label='Resampled Spectra (NIR: LIRIS)'),
                   Line2D([0], [0], color='k', lw=2, label='Accretion Disk Model')]
ax.legend(handles=legend_elements, fontsize=12)
# plt.savefig("sed_hbc722_NEW_min_chisq.png", dpi=200, bbox_inches='tight')
plt.show()

# %%
fig=plt.figure(figsize=(6, 9), dpi= 100)
gs = gridspec.GridSpec(2, 1,height_ratios=[5, 1])
plt.rcParams.update({'font.size': 10})

ax = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

ax.plot(WAV_DAT, FLUX_DAT, 'ro', markersize=1, alpha=1, label='Resampled Spectra')
ax.plot(model_wav,model_wav_flux, \
         'ko', markersize = 1,  label='Stellar Atmospheres \n Acc. Disk (unsmoothed)')

# plt.plot(model_wav[1], filtered_signal[1],'o' , markersize = 1, alpha=1, label='')
# ax.plot(model_wav[0], filtered_signal[0],'o' , markersize = 1,  label='')

# plt.plot(model_wav[2], filtered_signal[2],'o' , markersize = 1, alpha=1, label='')

# plt.plot(model_wav[3], filtered_signal[3],'o', color = 'tab:purple' , markersize = 1, alpha=1, label='')
# plt.plot(model_wav[4], filtered_signal[4] - 0.6,'o', color = 'tab:pink' , markersize = 1, alpha=1, label='')
# plt.plot(model_wav[5], filtered_signal[5] + 2.7,'o', color = 'tab:olive' , markersize = 1, alpha=1, label='')






# ax2.plot(model_wav, 100*(model_wav_flux - FLUX_DAT)/model_wav_flux, 'o', markersize=1)
# ax2.plot(model_wav, np.zeros(len(model_wav_flux)), 'k--')

# ax2.plot(model_wav, (1/0.4)*np.log10((10**filtered_signal)/(10**FLUX_DAT)), 'ko', markersize=1)


ax2.plot(model_wav, np.zeros(len(model_wav_flux)), 'k--')


plt.xlabel(r'log $\lambda$ ($\mu$m)')
# plt.ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$ + offset')
# ax2.set_ylabel(r'Percent Error')
# plt.ylim(-12.5, -8.7)
# plt.title('Model Creation: SED Components and Examples')
# ax.set_ylim(-13, -10.5)
ax.set_xlim(-0.5, 0.4)
ax2.set_xlim(-0.5, 0.4)

ax.legend()
# legend_elements = [Line2D([0], [0], color='tab:blue', lw=1, label=r'Disk Model, $T_{max} =$ 10,000 K'),
#                    Line2D([0], [0], color='tab:orange', lw=1, label=r'Disk Model, $T_{max} =$ 7000 K'),
#                    Line2D([0], [0], color='tab:green', lw=1, label=r'Disk Model, $T_{max} =$ 5000 K'),
#                   Line2D([0], [0], color='tab:purple', lw=1, label=r'7000 K Atmosphere'),
#                   Line2D([0], [0], color='tab:pink', lw=1, label=r'5000 K Atmosphere'),
#                   Line2D([0], [0], color='tab:olive', lw=1, label=r'3000 K Atmosphere')]
# plt.legend(handles=legend_elements,fontsize=9.5, ncol=2)
# plt.savefig("sed_demo.png", dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## MCMC Routine

# %%
def lnlike(theta, x, y, yerr):
    r_star, m_dot, a_v= theta
    
    m_star = (r_star/2)*M_SUN
    r_star = r_star*R_SUN

    
    m_dot = 10**m_dot 
    m_dot = m_dot* M_SUN / 3.154e7
    inc = 30
    dist = 795*3.08567758128e18
    pl_index = 0
    try:
    
        gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
        gaia17bpi_env.createFUOri(r_star = r_star, r_outer = R_OUTER, m_star = m_star,\
                              m_dot = m_dot, inc = inc, a_v = a_v, dist = dist, grav = 1.5, \
                                  direc = DIREC, atm_table=ATM_TABLE_INTERP, pl_index = pl_index)
    
    # Accounts for any random case where the model may not be generated properly given a certain combination
    # of parameters. This has only happened once, but it's presumably when the maximum temperature is too low.
    except:
        return 0
        
    
    # Converting units to properly compare model to data
    x_new = (10**x)*1e4
    modSpec = np.zeros(len(x_new))
    modSpec = gaia17bpi_env.fuori.mod_spec_lums
#     for i in range(len(x)):
#         modSpec[i] = gaia17bpi_env.getModSpecPoint(x[i], True)
    modSpec = pyasl.unred(x_new, modSpec, -a_v/3.1)
    flux = np.cos(np.radians(inc))*modSpec/(2*np.pi*(dist**2))
    

    model = np.log10(x_new*flux*1e-8)
    
    b, a = signal.butter(1, 0.35, 'low', analog=False)
    model = signal.filtfilt(b, a,  model)
    
    inv_sig = 1/yerr
    return np.sum(np.log((1/np.sqrt(2*np.pi))*inv_sig) - 0.5*((y - model)*inv_sig)**2)

# %%
M_STAR_LOW = 0.2
M_STAR_HIGH = 1.0


R_STAR_LOW = 0.2
R_STAR_HIGH = 8.0

M_DOT_LOW = -8.0
M_DOT_HIGH = -3.5

A_V_LOW = 2.8
A_V_HIGH = 3.8

PL_IND_LOW = -2.0
PL_IND_HIGH = 2.0

INC_LOW = np.cos(np.radians(90))
INC_HIGH = np.cos(np.radians(0))

DIST_LOW = 795 - 150
DIST_HIGH = 795 + 150

# %%
def lnprior(theta):
    r_star, m_dot, a_v= theta
    if M_DOT_LOW  < m_dot < M_DOT_HIGH \
    and R_STAR_LOW < r_star < R_STAR_HIGH\
    and A_V_LOW < a_v < A_V_HIGH:
        return 0.0
    return -np.inf

# %%
def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return (lp + lnlike(theta, x, y, yerr))

# %%
ndim, nwalkers = 3, 12
m_star_start = 0.5
r_star_start = 1.4
m_dot_start = -5.3
a_v_start = 3.6
pl_ind_start = 0
inc_start = np.cos(np.radians(60))
dist_start = 795
start = np.array((r_star_start, m_dot_start, a_v_start))
pos = [start + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]

# %%
x = WAV_DAT
y_meas = FLUX_DAT
y_err = FLUX_DAT_ERR

# %%
len(WAV_DAT), len(gaia17bpi_env.fuori.mod_spec_lums)
# Out:
# (435, 435)

# %%
lnprob((r_star_start, m_dot_start, a_v_start), x,y_meas,y_err)
# Out:
# 339.627216019539

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x, y_meas, y_err))
# %time sampler.run_mcmc(pos, 20000)
# Out:
# CPU times: user 12min 16s, sys: 2.6 s, total: 12min 19s
# Wall time: 12min 19s
# (array([[ 1.28242168, -5.4534478 ,  3.39304873],
#         [ 1.4015052 , -5.52534643,  3.05988832],
#         [ 1.46813363, -5.53639356,  2.96849833],
#         [ 1.3408362 , -5.4664215 ,  3.31022811],
#         [ 1.33521932, -5.47916083,  3.2639599 ],
#         [ 1.2994145 , -5.48567434,  3.27447389],
#         [ 1.38631145, -5.49344493,  3.196434  ],
#         [ 1.46835927, -5.52548912,  3.03509332],
#         [ 1.38418662, -5.49495324,  3.18761752],
#         [ 1.54432876, -5.52200081,  3.00587729],
#         [ 1.43579747, -5.50361111,  3.14441975],
#         [ 1.31385351, -5.46675687,  3.30294729]]),
#  array([556.3798715 , 556.79426494, 557.28452707, 556.30757653,
#         557.29444019, 556.69825683, 556.71310607, 557.00106338,
#         556.92198088, 554.85800595, 554.4630367 , 555.34044548]),
#  ('MT19937',
#   array([  20510424, 3681304918, 3423631503, 4088047220, 4130276746,
#          1479995075,   65536381, 2542890584, 3125970202,  563465734,
#          1079769681,  809168767, 3167665658,  654357346, 1778896130,
#          1093378003,  404331517, 1686483456, 1408838033, 1160711540,
#          2937406183, 3290118473, 1002588986, 1917707963, 2922969392,
#          1347898092, 2119399535, 3549214016, 2408315847, 1657973031,
#          1359007184, 4278237692, 3253062292, 2779698820,  646758447,
#          1389227665, 3404498817, 2579258141, 4159286598, 3517022800,
#             5389562,  199362469, 3187625571, 2346054854, 3591717552,
#          1511959883, 4215254742, 4049710026, 2850491135, 3733300524,
#          1518119851,  834980531, 3113060458, 1342811420, 3499365400,
#          1022318915,  527379567, 1172343104, 4024333659,  710941001,
#          3969844375, 1106215194, 2444916938, 3938392916, 3974498320,
#          3064927009,  409571496, 3513847553, 3394691357, 2831454553,
#           798364794,  344948304,  376136245, 3901318339, 3484812316,
#          1740414540, 1745726618, 3165235163,  615075545,  234177604,
#           176385415, 2086578837,  196055630, 1579840685, 2756046724,
#          3188704087, 3330817813, 3307528914, 3327811229, 3489065463,
#          4160332886, 4267421628,  280246104, 1572181571,  396725885,
#          2088006322, 1265753538,  824141794, 2344797094, 1268578265,
#          1459579137,  304202716, 1420965105, 4281269220, 2254579576,
#          3209885494, 1131785027, 2110950998,  446593006,  799195990,
#          2171067370, 3354916408, 1444820563, 3999295630,  412235115,
#          2576562617, 3136355383, 2472148162, 1796594685, 2081219707,
#          3507658433,  390345828, 2304540686, 1228400387, 1278232689,
#          3401327843,  489355088,  445652110, 1616015792,  764319006,
#          2254424889, 2285597261, 4291813594,  985705952,  483924147,
#          3397269296, 3338651632, 3769925300,  709937632, 2900321488,
#          2776142516,  939319645, 1926574459, 3460234329, 3149948064,
#          2847560342,  127665676,  705433932, 1631702130,  112601273,
#          1508335905, 1543703269, 3378050586, 3975770068,  601553643,
#          3069599140,  702938243, 3442001151, 3851905794,  396307354,
#          2468152432, 3651660644, 2113468345, 1295065084, 3304164920,
#          2674876429,  567448563,   60844247,  125640254, 4022366313,
#           799549623, 3960476431, 1077297780,  831528766, 4143957010,
#           637602463,  599993695, 1773098928,  700469300, 3923174998,
#          2761151420, 1615783314, 2202152776, 3242943737,  450672415,
#           949515050, 3464048911, 3608263088, 3313522961, 1759690836,
#          3706284156, 3896265884, 2403671377, 2669985225, 2902349391,
#          3902919330, 1726007344,  839934415, 4188547232, 1650161047,
#          3498765811, 3741697909, 3988764525,  889855996, 4244133567,
#          1439878994, 2839841945,  663031248, 3346291047,  918411326,
#          3050392934,  238760126, 3183750178,  832540466, 2676616736,
#          2447464949, 3284411668, 1421362655, 3922366454, 1891139449,
#          1645062199, 1877889114, 1197433142,  453009236, 1260280645,
#          3469153399, 1346669794, 3567244979, 1140669819, 2440911579,
#          3089577661, 1481472221, 2412707141, 3453059207, 2236819997,
#          1088372084,  573685101,  573454275, 3028537344, 1904810312,
#          3972072551, 3831442453, 1088352604, 1262489427,  358204037,
#          3284952020, 1800291262, 3418076999, 3387355918, 2436018859,
#          1198326177, 2069278427, 4176822522, 2848698532, 1000303059,
#           607638540, 1631067814, 3938442185,   83676596,  429213440,
#          3466038579,  382388447, 2474476602, 2434340778, 1811823339,
#          1351198326,  670290404, 2295824716,  653122012, 3650945964,
#          1485703091, 1585252852,   75149107, 2752729877, 2210559946,
#           203374133, 1137193927, 3688339836, 1024973255, 3896366054,
#           362984818, 3659136310, 1522978663, 2213945086, 2105655596,
#          1063874908, 1628605805, 3478322511,   61646347, 1947011583,
#          3834578031, 3396045638, 4247418845, 2727663439, 1338367931,
#          1109067140, 1532539759, 2830241968, 1625137350,   97831782,
#          1177021148, 2378491898, 4166761059, 4099773001, 1538510637,
#          3314661643, 2557908243, 4232778930, 2921678333, 2392137495,
#          1294898031, 3498827495, 1588559498, 3775349062, 3706934067,
#           907976981, 4087251335,  731035505,  134014300, 1802958261,
#          2308381406, 1097820855, 3150656152, 1118494548, 2675217138,
#          1313055431, 3060708808, 3919337090, 1981652914, 2581037920,
#          3667472015, 2992049884, 3115190549,  136745324, 3192416165,
#           783211151,  196979971, 1458540526, 1865242793, 1524418162,
#          3797622128, 1534703519, 1945660812, 1822327472,  176103480,
#          2566958029,  876397064, 2062194803, 2250345864, 2923563487,
#          1548047786, 1740309306,  691945173, 1208559679, 3882416947,
#           630495926, 2849569364, 1742298023,  419891794, 2243660418,
#           843751672,   61211536, 3386245419, 3335073342, 2272094138,
#          3347107390, 3323278279, 1566649993, 2090236554,  502587846,
#          2664935939, 3030425018, 4116828471,  120567130, 2610566729,
#          3324755908, 4150026394, 2414177868, 2173811772, 2775833598,
#          1360264265, 2560946169, 1107140423, 1968905574,  613177724,
#          1954829565, 1809197003, 2123577501,  631186806, 3407599685,
#          2651757880,  755237434, 1472187659, 1311094596, 2763771808,
#           909323321, 3227944541, 3019245795,  766307402, 3182931824,
#          2768587998, 2057296544, 3305229474, 2372593086, 3220647472,
#          3872982930, 4214485341, 1058278979, 1770320125,  785510468,
#          1847698713, 3841432865,  526366967, 4063786671, 4047263003,
#           600957868, 2223257159, 2575734523, 3692742405, 3751776989,
#          3162332806, 2328376880, 1569813589, 4032015382, 3780844649,
#          2193405787,  445191956, 3812082741, 1373332713, 1887536142,
#          3225529652, 2720583682, 2799807087, 4215935753, 2470339979,
#          3349723489, 1601154554,  359749693, 3217878263, 1843977015,
#          1127069250, 2948294810, 3083371518, 2851413432,  363745610,
#          2446227255, 2337736188, 2541471560,  789110021, 3466790118,
#          2999866311,  947159867, 2714656488, 1419110553,  483462436,
#          1222739589, 2382267071, 1544870751, 1654987846, 3005614149,
#          2646620464,   21054464, 3368938123, 3491345215,  759892102,
#          2581290408, 2500427041, 1214760811,  799996663, 1800147532,
#          2560174925, 4228573336, 1085893602, 2024746620, 3465750455,
#          3614903405,   14537924, 1465653695, 3778579131,  178952551,
#          3515247088, 1910969029, 1587393665, 1581518486, 2039818397,
#           703879161, 1115829009, 1766958294, 2530459044, 3938096788,
#          4035968932, 1053373432, 2701674666, 4055402805, 3237832457,
#          2887396164, 4052933415, 2154324237, 1028280417, 1471895961,
#          1569265325, 1209674558, 1588610387, 3982912060, 2135789635,
#           230363202, 3527485630, 2920336417,  481689114, 2385498425,
#          1609409021,  886297987, 2489019953, 3552511400, 1892208555,
#          1902541842,  779488229, 3531209593, 3510590965,  230439582,
#          3651474707, 3923035050,  647790771,  403933754, 4029253742,
#          2900605824, 1635253891,  324112705, 3219145264,  707440215,
#          3694625078, 1479677210, 3630598816, 3899218438, 3537449571,
#          1703480930, 2105725490, 1447253752, 2019527777, 1363496553,
#          3902922543, 3341729034, 3040787198, 3904498529, 1618748091,
#           194398648, 1935750043, 2340655064, 3299436140, 1094661636,
#          2600659949, 4042287973,  367964884, 1355861906, 3099305010,
#           488151134, 2187735254, 3429358667, 2541456786, 3218476894,
#          1952109566, 4182721976, 1452741366,  172029682, 4129952418,
#           609571256, 2949260140, 2551061991, 3217742138, 1905054195,
#          3792763186,  899100775, 2662693966, 2263941237, 2866088555,
#            69898380, 1222773636, 3045296853, 3529198090, 3635287699,
#          1730762489,  324703183, 3361493528, 3094000159, 4094983184,
#          1063298886,   20705803, 2364451765, 1561568946, 1426841725,
#          3378697071, 1349777477, 1381504271, 2921128365, 2780836749,
#          1813727112, 3542416759, 3347275865,  427881956, 2979616732,
#          4171704139, 2599175612,  401719073, 2576190672, 4142560736,
#          2857348146, 2489618609, 2299798735, 3460480717, 4059093850,
#           508824157, 4181433906, 1806436003, 3784475784, 3742686353,
#           673095325, 3535520637, 3660160144, 2259812792,  213012792,
#          1879081844, 3364878426, 2099885099, 3237674289], dtype=uint32),
#   526,
#   0,
#   0.0))

# %%
samples = sampler.chain[:, 10000:, :].reshape((-1, ndim))
fig = plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 16})

plt.plot(samples)
plt.xlabel('Step number')
plt.ylabel('Estimated values of parameters')
plt.title('Evolution in estimated values using MCMC')
plt.xticks([])
plt.show()

# %%
median_calcuated = np.median(samples, axis=0)

fig = corner.corner(samples, labels=[r'$R_*$*', r'$\log \dot{M}$', r'$A_V$'], verbose=True,
                       quantiles=(0.16, 0.5,0.84), plot_contours=True, scale_hist=True,
                       show_titles=True, title_kwargs={"fontsize": 16})

axes = np.array(fig.axes).reshape((ndim, ndim))

for i in range(ndim):
    ax = axes[i, i]
    ax.axvline(median_calcuated[i], color="r")
    
for yi in range(ndim):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(median_calcuated[xi], color="r")
        ax.axhline(median_calcuated[yi], color="r")
        ax.plot(median_calcuated[xi], median_calcuated[yi], "sr")

fig.show()
# fig.savefig("hbc722_corner_all.png", dpi=180)
# Out:
# Quantiles:
# [(0.16, 1.2938372146887513), (0.5, 1.4011214817509758), (0.84, 1.5029667987079673)]
# Quantiles:
# [(0.16, -5.542034267922193), (0.5, -5.5047505163521055), (0.84, -5.468079345705346)]
# Quantiles:
# [(0.16, 2.9503396172374052), (0.5, 3.14584636606676), (0.84, 3.326911493012415)]
# /Users/tonyrodriguez/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
[0.71, 0.63, -5.41, 4.08, 1.56]
