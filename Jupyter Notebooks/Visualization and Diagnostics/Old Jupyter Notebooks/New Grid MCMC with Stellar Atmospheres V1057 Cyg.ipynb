# %% [markdown]
# # New Grid MCMC with Stellar Atmospheres

# %% [markdown]
# Started 29 October 2019. This notebook is meant to (finally) incorporate stellar atmospheres into the MCMC fit. Resampling is done in the actual MCMC to not have too many points. Let's see how this works. Interpolating the grid of stellar atmospheres onto the same grid as the points for fast computation.

# %% [markdown]
# ### Imports

# %%
import numpy as np
from scipy import optimize
from scipy import interpolate
from scipy import integrate
from astropy.convolution import convolve, convolve_fft
import matplotlib.pyplot as plt
from fu_ori_functions_oct29 import *
from fu_ori_classes_oct29 import *
import matplotlib.gridspec as gridspec

import emcee
import corner
import time
# %matplotlib inline

# %%
G = 6.67259e-8
SIG_SB = 5.67051e-5
M_SUN = 1.99e33
R_SUN = 6.96e10
L_SUN = 3.839e33
h_PLANCK = 6.6260755e-27
c_LIGHT = 2.99792458e10
k_BOLTZ = 1.380658e-16

# %%
ATM_TABLE = dict()
ATMOS_FACTOR = 100

# %%
def getDataArrayMOD(data_file):
    txt = open(data_file)
    fulltxt = txt.readlines()
    # Cleaning lines
    newtxt = []
    for i in range(0,len(fulltxt), 2):
        line = fulltxt[i][:-1]
        line = line.split()
        if line[0] == '#':
            line = [line[1], line[2]]
        newtxt.append(line)
    # Casting as floats
    newtxt = np.array(newtxt).astype(np.float64)
    return newtxt

# %%
def direcToArray(directory):
    for temp in range(2000, 10000+ATMOS_FACTOR, ATMOS_FACTOR):
        for grav in [1.5, 4.0]:
            try:
                atmos_file = directory + 'pr.lte' + str(int(temp/ATMOS_FACTOR)) \
                        + '-' + str(grav) + '-0.0.spec'
                txt = open(atmos_file)
                fulltxt = txt.readlines()
                # Cleaning lines
                newtxt = []
                for i in range(len(fulltxt)):
                    line = fulltxt[i][:-1]
                    line = line.split()
                    newtxt.append(line)
        
                # Casting as floats
                newtxt = np.array(newtxt).astype(np.float64)
                
                # Choosing which model to use
                wav, lum = newtxt[:,0], newtxt[:,1]
                ATM_TABLE[(temp, grav)] = np.array([wav, lum])
            except:
                print('No atmosphere found for temp = ' + str(temp) + \
                      ' grav = ' + str(grav))

# %%
direcToArray('C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/')
# Out:
# No atmosphere found for temp = 7100 grav = 1.5
# No atmosphere found for temp = 7100 grav = 4.0
# No atmosphere found for temp = 7300 grav = 1.5
# No atmosphere found for temp = 7300 grav = 4.0
# No atmosphere found for temp = 7500 grav = 1.5
# No atmosphere found for temp = 7500 grav = 4.0
# No atmosphere found for temp = 7700 grav = 1.5
# No atmosphere found for temp = 7700 grav = 4.0
# No atmosphere found for temp = 7900 grav = 1.5
# No atmosphere found for temp = 7900 grav = 4.0
# No atmosphere found for temp = 8100 grav = 1.5
# No atmosphere found for temp = 8100 grav = 4.0
# No atmosphere found for temp = 8300 grav = 1.5
# No atmosphere found for temp = 8300 grav = 4.0
# No atmosphere found for temp = 8500 grav = 1.5
# No atmosphere found for temp = 8500 grav = 4.0
# No atmosphere found for temp = 8700 grav = 1.5
# No atmosphere found for temp = 8700 grav = 4.0
# No atmosphere found for temp = 8900 grav = 1.5
# No atmosphere found for temp = 8900 grav = 4.0
# No atmosphere found for temp = 9100 grav = 1.5
# No atmosphere found for temp = 9100 grav = 4.0
# No atmosphere found for temp = 9300 grav = 1.5
# No atmosphere found for temp = 9300 grav = 4.0
# No atmosphere found for temp = 9500 grav = 1.5
# No atmosphere found for temp = 9500 grav = 4.0
# No atmosphere found for temp = 9700 grav = 1.5
# No atmosphere found for temp = 9700 grav = 4.0
# No atmosphere found for temp = 9900 grav = 1.5
# No atmosphere found for temp = 9900 grav = 4.0
# No atmosphere found for temp = 10000 grav = 1.5

# %% [markdown]
# ### Interpolating grid of stellar atmospheres on same grid as data:

# %% [markdown]
# First, reading in data...

# %%
txt_in = getDataArrayMOD('v1057_out.csv')
WAV_DAT = txt_in[:,0]
FLUX_DAT = txt_in[:,1]
FLUX_DAT_ERR = -0.01*FLUX_DAT

# %%
import spectres

# %%
def getInterpTable(st_atm_table, waves_data):
    out_table = dict()
    for key in ATM_TABLE:
        wav, lum = ATM_TABLE[key]
#         interp_func = interpolate.interp1d(wav, lum, kind = 'linear')
#         out_table[key] = waves_data, interp_func(waves_data)
        out_table[key] =  waves_data, spectres.spectres(waves_data, wav, lum)
    return out_table

# %%
WAVES_DATA_LOGGED = WAV_DAT

# %%
len(WAVES_DATA_LOGGED)
# Out:
# 258

# %%
WAVES_DATA = 1e4*(10**WAVES_DATA_LOGGED)

# %%
ATM_TABLE_INTERP = getInterpTable(ATM_TABLE, WAVES_DATA)

# %%
ATM_TABLE_INTERP.keys()
# Out:
# dict_keys([(2000, 1.5), (2000, 4.0), (2100, 1.5), (2100, 4.0), (2200, 1.5), (2200, 4.0), (2300, 1.5), (2300, 4.0), (2400, 1.5), (2400, 4.0), (2500, 1.5), (2500, 4.0), (2600, 1.5), (2600, 4.0), (2700, 1.5), (2700, 4.0), (2800, 1.5), (2800, 4.0), (2900, 1.5), (2900, 4.0), (3000, 1.5), (3000, 4.0), (3100, 1.5), (3100, 4.0), (3200, 1.5), (3200, 4.0), (3300, 1.5), (3300, 4.0), (3400, 1.5), (3400, 4.0), (3500, 1.5), (3500, 4.0), (3600, 1.5), (3600, 4.0), (3700, 1.5), (3700, 4.0), (3800, 1.5), (3800, 4.0), (3900, 1.5), (3900, 4.0), (4000, 1.5), (4000, 4.0), (4100, 1.5), (4100, 4.0), (4200, 1.5), (4200, 4.0), (4300, 1.5), (4300, 4.0), (4400, 1.5), (4400, 4.0), (4500, 1.5), (4500, 4.0), (4600, 1.5), (4600, 4.0), (4700, 1.5), (4700, 4.0), (4800, 1.5), (4800, 4.0), (4900, 1.5), (4900, 4.0), (5000, 1.5), (5000, 4.0), (5100, 1.5), (5100, 4.0), (5200, 1.5), (5200, 4.0), (5300, 1.5), (5300, 4.0), (5400, 1.5), (5400, 4.0), (5500, 1.5), (5500, 4.0), (5600, 1.5), (5600, 4.0), (5700, 1.5), (5700, 4.0), (5800, 1.5), (5800, 4.0), (5900, 1.5), (5900, 4.0), (6000, 1.5), (6000, 4.0), (6100, 1.5), (6100, 4.0), (6200, 1.5), (6200, 4.0), (6300, 1.5), (6300, 4.0), (6400, 1.5), (6400, 4.0), (6500, 1.5), (6500, 4.0), (6600, 1.5), (6600, 4.0), (6700, 1.5), (6700, 4.0), (6800, 1.5), (6800, 4.0), (6900, 1.5), (6900, 4.0), (7000, 1.5), (7000, 4.0), (7200, 1.5), (7200, 4.0), (7400, 1.5), (7400, 4.0), (7600, 1.5), (7600, 4.0), (7800, 1.5), (7800, 4.0), (8000, 1.5), (8000, 4.0), (8200, 1.5), (8200, 4.0), (8400, 1.5), (8400, 4.0), (8600, 1.5), (8600, 4.0), (8800, 1.5), (8800, 4.0), (9000, 1.5), (9000, 4.0), (9200, 1.5), (9200, 4.0), (9400, 1.5), (9400, 4.0), (9600, 1.5), (9600, 4.0), (9800, 1.5), (9800, 4.0), (10000, 4.0)])

# %%
class FUOriEnvironment:
    
    # Initializer / Instance Attributes
    def __init__(self, wave_lower_SED, wave_upper_SED):
        
        self.wave_lower_SED = wave_lower_SED
        self.wave_upper_SED = wave_upper_SED
        
        # Storing classes
        self.fuori = 0
        
    # instance methods
    
    # Creating FU Ori object as accretion disk
    def createFUOri(self, r_star, r_outer, m_star, m_dot, inc, dist, grav, direc, a_v, atm_table):
        fuori = FUOri(r_star, r_star, r_outer, m_star, m_dot, np.radians(inc), a_v, atm_table)
        fuori.setAnnuliValues(10000, 2000, 200, 2*R_STAR)
        fuori.createAnnuliFromDirec(grav, direc, 'stellar atmospheres')
        fuori.createModelSpectrum('stellar atmospheres', True)
        self.fuori = fuori

# %% [markdown]
# ### Making an instance of the class

# %%
M_STAR =1.98*M_SUN
R_STAR= 2.88*R_SUN
R_OUTER = 100 * R_STAR
M_DOT = (10**0.99) * 1e-6 * M_SUN / 3.154e7

A_V = 3.59
INC = 45.
DIST = 795*3.08567758128e18
DIREC = 'C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/'

# %%
# %time gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
# %time gaia17bpi_env.createFUOri(r_star = R_STAR, r_outer = R_OUTER, m_star = M_STAR,\
                          m_dot = M_DOT, inc = INC, a_v = A_V,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)
# Out:
# Wall time: 0 ns
# Wall time: 11 ms

# %%
wav, lum = gaia17bpi_env.fuori.mod_spec_waves, gaia17bpi_env.fuori.mod_spec_lums

# %%
gaia17bpi_env.fuori.annuli[0].temp, gaia17bpi_env.fuori.getTotalLum()/L_SUN
# Out:
# (7000.0, 104.43116063613785)

# %% [markdown]
# ### Plotting data with model

# %%
model_wav = np.log10(wav*1e-4)
model_wav_flux =  np.log10(lum*wav*1e-8*np.cos(np.radians(INC))/(2*np.pi*DIST**2))

# %%
fig=plt.figure(figsize=(6, 8), dpi= 100)
gs = gridspec.GridSpec(2, 1,height_ratios=[3, 1])
plt.rcParams.update({'font.size': 14})

ax = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])


# plt.errorbar(WAV_DAT, FLUX_DAT, yerr=FLUX_DAT_ERR, marker='o', \
#              linestyle='', color='r', alpha=1, label='Palomar + IRTF \nResampled Spectra')

ax.plot(WAV_DAT, FLUX_DAT, 'ro', markersize=1, alpha=1, label='Resampled Spectra')
ax.plot(model_wav,model_wav_flux, \
         'ko', markersize = 1,  label='Stellar Atmospheres \n Acc. Disk')

ax2.plot(model_wav, 100*(model_wav_flux - FLUX_DAT)/model_wav_flux, 'o', markersize=1)
ax2.plot(model_wav, np.zeros(len(model_wav_flux)), 'k--')


ax2.set_xlabel(r'log $\lambda$ ($\mu$m)')
ax.set_ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$')
ax2.set_ylabel(r'Percent Error')

ax.set_title('V1057 Cyg SED: Post-MCMC Fit')
ax.set_ylim(-11, -8)
ax.set_xlim(-0.5, 0.4)
ax2.set_xlim(-0.5, 0.4)

ax.legend()
# plt.savefig("sed_gaia17bpi_75.png", dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## MCMC Routine

# %%
def lnlike(theta, x, y, yerr):
    m_star, r_star, a_v, m_dot = theta
    r_star = r_star*R_SUN
    
    m_dot = 10**m_dot
#     m_star = 10**m_star
    m_star = m_star*M_SUN
    
    m_dot = m_dot* 1e-6 * M_SUN / 3.154e7
    try:
    
        gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
        gaia17bpi_env.createFUOri(r_star = r_star, r_outer = R_OUTER, m_star = m_star,\
                              m_dot = m_dot, inc = INC, a_v = a_v, dist = DIST, grav = 1.5, \
                                  direc = DIREC, atm_table=ATM_TABLE_INTERP)
    
    # Accounts for any random case where the model may not be generated properly given a certain combination
    # of parameters. This has only happened once, but it's presumably when the maximum temperature is too low.
    except:
        print('Weird array error')
        gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3)
        gaia17bpi_env.createFUOri(r_star = R_STAR, r_outer = R_OUTER, m_star = M_STAR,\
                              m_dot = M_DOT, inc = INC, a_v = A_V, dist = DIST, grav = 1.5, \
                                  direc = DIREC, atm_table=ATM_TABLE_INTERP)
        
    
    # Converting units to properly compare model to data
    x = (10**x)*1e4
    modSpec = np.zeros(len(x))
    modSpec = gaia17bpi_env.fuori.mod_spec_lums
#     for i in range(len(x)):
#         modSpec[i] = gaia17bpi_env.getModSpecPoint(x[i], True)
    flux = np.cos(np.radians(INC))*modSpec/(2*np.pi*DIST**2)

    model = np.log10(x*flux*1e-8)
    inv_sig = 1/yerr
    return np.sum(np.log((1/np.sqrt(2*np.pi))*inv_sig) - 0.5*((y - model)*inv_sig)**2)

# %%
M_STAR_LOW = 0.2
M_STAR_HIGH = 4.0
R_STAR_LOW = 0.3
R_STAR_HIGH = 8.0

M_DOT_LOW = -1.5
M_DOT_HIGH = 3.5

A_V_LOW = 2.
A_V_HIGH = 5.

# %%
def lnprior(theta):
    m_star, r_star, a_v, m_dot= theta
    if M_DOT_LOW  < m_dot < M_DOT_HIGH \
    and M_STAR_LOW < m_star < M_STAR_HIGH\
    and A_V_LOW < a_v < A_V_HIGH\
    and R_STAR_LOW < r_star < R_STAR_HIGH:
        return 0.0
    return -np.inf

# %%
def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return (lp + lnlike(theta, x, y, yerr))

# %%
ndim, nwalkers = 4, 14
m_star_start = 1.
r_star_start = 3.2
a_v_start = 3.9
m_dot_start = 1.5
start = np.array((m_star_start, r_star_start, a_v_start, m_dot_start))
pos = [start + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]

# %%
x = WAV_DAT
y_meas = FLUX_DAT
y_err = FLUX_DAT_ERR

# %%
len(WAV_DAT), len(gaia17bpi_env.fuori.mod_spec_lums)
# Out:
# (258, 258)

# %%
lnprob((m_star_start, r_star_start,a_v_start, m_dot_start), x,y_meas,y_err)
# Out:
# 125.22798907181769

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x, y_meas, y_err))
# %time sampler.run_mcmc(pos, 5000, progress=True)
# Out:
# C:\Users\tonyc\AppData\Local\Continuum\anaconda3\lib\site-packages\emcee\ensemble.py:258: RuntimeWarning: Initial state is not linearly independent and it will not allow a full exploration of parameter space
#   category=RuntimeWarning,
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [07:56<00:00, 10.50it/s]
# Wall time: 7min 56s
# State([[3.49866831 3.07791002 3.49307856 0.75187642]
#  [1.40686881 2.72654736 3.73837996 1.14459941]
#  [0.67632299 2.67208683 3.82079306 1.46019534]
#  [1.82655669 3.25223422 3.11988195 0.97226283]
#  [2.17519714 2.74835675 3.71150146 0.94764451]
#  [2.65093453 2.65136888 3.80060395 0.86301236]
#  [0.35682897 3.05153703 3.38196677 1.70682944]
#  [3.84102483 2.89148625 3.5266711  0.67758476]
#  [2.82970195 2.78951491 3.72664097 0.84300378]
#  [3.95410325 2.98367949 3.38799034 0.65668554]
#  [2.532686   2.72640229 3.73309437 0.88375317]
#  [0.56610542 2.90368581 3.65360356 1.54837921]
#  [2.53836084 2.75567107 3.68318219 0.8702136 ]
#  [0.35420794 2.81326696 3.71740539 1.74016084]], log_prob=[248.27015578 249.05961278 247.94755538 246.26423035 250.00629629
#  249.71549736 249.92109625 249.15237468 249.5424035  249.89309938
#  249.94290707 249.26811117 249.58184676 247.61559461], blobs=None, random_state=('MT19937', array([1586716114, 3342391615, 3602039247, 2851451813, 1565840137,
#        1269547500, 2654963020, 2195866458, 2647289090, 2983177348,
#        4105543270, 2386504207, 2928746418, 1993101444,  874677225,
#        2129988242, 3699771413, 4061511118, 3208487650, 1105720005,
#        1542679090,  423728560,  732977641, 1914143395, 3489688975,
#        1804073470, 3093536343, 1987458893, 2427263039, 2565064552,
#        1867292263, 1922758473, 2854413556, 3760238529,  488852160,
#        3724524065, 1057917857, 2858692382, 4031071241, 2296682289,
#        3992182708, 1661618962,  319049655, 1267888862,  250699466,
#         220191719, 2711882972, 2362268867, 2731342219, 4110938460,
#        2259944003, 4096247272, 2717663509, 3842013187, 2440868689,
#        1541767783, 3499982423, 3659901063,  848486156, 2974277182,
#        1023062476, 3634262324, 2714724616, 2673861884, 1109842145,
#        2579452223, 3697448144, 3117106404,  682889572, 2372404734,
#        1742406188, 2033594445,  159044188, 2713196379, 2252518829,
#        3121255012, 1718623606, 2964157710, 2698340152, 2806091173,
#        2758265683, 3303513669, 2893350320, 1148934327, 4098863955,
#        1288294478, 1997172602,  189247972, 1242677329, 3840154611,
#         446706938, 3710308081, 2551623582, 2571054290, 1590138745,
#        2877004648, 1430656224, 1195668949, 2690542660,  955407283,
#        3680454969,  394669966, 1775509522, 1086855593,  586921486,
#        1823156354, 3038658561, 3998370127, 4052081033,  630375332,
#        3258167561,   14941800,  733635230, 2797075711, 1351564221,
#        1936443843,  242599381,  556005347,  793191438,  549575372,
#        2250818391,  433703146, 2557356693, 4252587840, 2016458000,
#        3606426840, 3298936192,  343172137,  825486557, 2066793820,
#         386427047,  583311984,  368315285, 1895386045, 3189836729,
#        1661940677, 3820352602, 1454516196, 3899243027, 1986957258,
#        3788923625,  105256068,  264018374,  837660163, 4238138509,
#        2007865753, 2617725887, 1244605404, 3759344927, 2341481021,
#        3070943003,  774847767, 3440653365, 3113450063, 3133767088,
#        3856013668, 1406458982, 3322402782,  859739255, 3212914568,
#         478365229, 2173071247,  514480074, 1751928186, 4247320624,
#        1808905617, 1444783337, 3862720591,  254314370, 1605634152,
#        3840304945,  172626219, 3410528126, 1618532028, 1816365897,
#        2554484979,  760721159,  216290693, 2034837766, 2836219664,
#        4247365512, 1890090649, 2980404022, 4095148873, 3709384431,
#        4182508178, 4100334915,  422789384, 1783059567, 1649361354,
#        1186159769, 4111040152, 1142381200, 1397942807, 1576140213,
#        1226970402, 3089152396, 1862711444,  228308710, 1865411447,
#        2627537631,  156301895, 3481699697, 4017266540, 1108166992,
#        3791485985, 1725655982,  829741923, 3644893607, 1341210816,
#        3860281696, 3779324168, 3652497594, 3076744796, 3595688837,
#        1168783336, 3442494845, 3973492473, 2702120347, 3782663619,
#        2511283477, 3322785369,  672337678,  592439027, 4238938414,
#        3422994552, 3224549510, 3027603980, 3971914051,  935310189,
#        2522932577, 1085838213,  276589255, 1528704815, 3950787492,
#        2504613691, 2573677234,  656363876, 1150202051,  228420721,
#         132201102, 2058075834, 2034429098, 2836028682, 1698888358,
#        2162174680, 3885707650, 4231026812, 2658020903,  485833342,
#        2109149880, 3248610401,  804776869,  303642935, 2425140310,
#         899295292, 1979430193, 1342237794, 3024412992, 3306979160,
#        3862523400, 1659115098, 2856761167,  825271038,  125169582,
#        3939444623, 1632570388, 2975106614, 2032342367, 1512501543,
#        1112539148, 2876134043, 2405848852, 3493958164,  447475087,
#         411868058, 2160101746,  496015405,  399387172, 2918428681,
#         981139571, 4208636296, 3695145163, 2467594447, 1272019642,
#        1466853501, 3170253905, 1536474939, 2683570009, 3405058579,
#        1818878119, 1944506192, 2241782676, 2911981735, 1901526931,
#         918222428,  705162656, 3094747320, 3021616120,  361983121,
#         211990267, 1348042790, 1544765052,  795012521, 4202969377,
#        3476497155, 2885594062,  869293591, 4276569195, 1591164019,
#        2138815848, 2300524997, 2360475307, 1187726826, 1916612658,
#        4290604299,  275730836, 4130401596, 1262609414, 1358864749,
#         101050359,   38004045, 1770918617,  642017669, 2226055731,
#         390327656, 1913371048,  248757655,  199781841, 3873019325,
#        2761616060, 1512458025, 3283985719, 1303169182, 2602508009,
#        1952386989, 3277009746,  527518685,  989599783, 2030679797,
#        1696871589,  112558701, 3824576310, 2857046474, 2043760922,
#        3461148888, 3229683806, 2960622288, 1017005387, 1391322590,
#        1442307241, 1444064880, 4242978861, 1809403912, 4118352984,
#        1857559885, 1879416017, 1960891332, 1862417196, 3051069860,
#        2233203312, 2531826644, 3168094895, 2570523971, 1951994293,
#        2440088657,  109519963,  561164570, 2840250045, 2465667978,
#        1874769334, 1597902742, 1483190908,  127208662, 1962749171,
#        1635722797, 1532191488, 3979866164, 2503458429, 3907555302,
#        3163363996, 2326176220, 2746804202, 2071614861, 2460637670,
#        2724252456, 4176499274, 3240267525,  726609136, 3608928381,
#        3059748597, 2897626816, 1341126138, 1672460321, 1549673194,
#        1868142675, 1998920928, 2493588097, 2086788622, 3303441399,
#         919516235, 2306430376, 3920862499,  480828515, 1331432689,
#        2846331666,  685703337,  300839485, 1590893526, 3333055258,
#        2156301474, 2180930141, 3870196543, 2857460050, 3734700075,
#        1043593805,  792011913,  853557001,  912698066, 4150920001,
#        3882767696, 3576987257, 1143480147, 3329585730,  724962620,
#        2649641737, 3313241175,  352620446, 3727994809, 4293933017,
#        3624499720,  689558784, 1472710385, 1144258846, 4107586235,
#        1464269356,  257268259,  895153639, 3793166788,  638468699,
#         691410556,  212267397,  668751373,  118346562, 2379235491,
#        1611684136,  845959256,  322624699, 2496918845,  782101258,
#         393275421, 2320504025, 1469192303, 2027697909, 2120691480,
#        2453772362, 1521845180, 4261052079, 2802558269,  577950792,
#        2579561741, 2236430591, 1106210250, 1382052063, 4279315689,
#        3652274471, 2272370839, 4277658150, 3985279482,  301347224,
#        1820288750, 1695043745, 4184488824, 2346436115, 2460436454,
#         561323836, 1950946031,  506730763, 1393393958, 1780775991,
#        3310193330, 3860556333, 3703662285, 1593064430, 3987318235,
#        1891895444, 4059257979, 3749179585, 3460493905, 2461631566,
#        2914398174, 2004342052,  895283335, 3734553466, 1335630272,
#        1858624777,  465976763, 1252048956,  166025951, 1992603953,
#        2283273901,  460251810, 3067429765,  334071526, 1621064727,
#        2588273266, 1345504820, 4006046794,    2256567, 2869274773,
#         316084830, 2337154670, 3328950927, 4237594052, 1960929038,
#        3751889084, 1660655356, 1064778225, 3312574943, 1986585262,
#         306994089,  702160996,  317741557, 2170567972,  813764976,
#        1129702204, 2038884731, 2174085450, 2388633620, 3467142696,
#        3791703569,  498395068,  399824856,  989950950, 2409930597,
#        2786250295, 2579694031, 4251223346, 3094073280, 1590022289,
#         446403964, 4002386577, 4029616125, 4206391263, 1111773857,
#        4203556556,   88591587,  690583350, 2753559411, 1396631465,
#        1581127960, 4025128698, 2064837242, 3143645383, 1822574297,
#        1429687647, 2270972286, 2490675964, 4228684109,  741540572,
#        4077265149, 3603113176, 1014817886, 2565017705, 2421285987,
#        3902398573, 3036965830, 3464810571,  997209480, 1492456120,
#        2318858897, 2781863114, 2477166366, 3122994765, 3181692440,
#        1945989939, 2801024530, 1375418373, 2332924657, 1848974586,
#         381708142, 3914907592, 3678025178, 3911905123, 1200324825,
#        3743438891, 1117226731, 2271144328,  830763224, 1574579087,
#         326280120, 3711327041, 3599634757, 4067736802,   19403467,
#        2741969958,  858847385, 2277043954,   83041228, 1807501526,
#        1444364526,  587564424, 3699780317, 2120523104, 1050638951,
#        2877017071, 1066310232, 3670797422,  818840210, 3955109914,
#        2927738318,  399358375,  928623978, 1262442389,  859371814,
#        2090617999,  854222895, 2127869260, 1900291765, 1303948496,
#        2775154854, 4137118108, 1528674179,  409776649], dtype=uint32), 418, 0, 0.0))

# %%
samples = sampler.chain[:, 2500:, :].reshape((-1, ndim))
fig = plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 16})

plt.plot(samples)
plt.xlabel('Step number')
plt.ylabel('Estimated values of parameters')
plt.title('Evolution in estimated values using MCMC')
plt.xticks([])
plt.show()

# %%
median_calcuated = np.median(samples, axis=0)

fig = corner.corner(samples, labels=[r'$ M_*$', r'$R_*$',r'$A_V$', r'$\log\;\dot{M}$'], verbose=True,
                       quantiles=(0.16, 0.5,0.84), plot_contours=True, scale_hist=True,
                       show_titles=True, title_kwargs={"fontsize": 12})

axes = np.array(fig.axes).reshape((ndim, ndim))

for i in range(ndim):
    ax = axes[i, i]
    ax.axvline(median_calcuated[i], color="r")
    
for yi in range(ndim):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(median_calcuated[xi], color="r")
        ax.axhline(median_calcuated[yi], color="r")
        ax.plot(median_calcuated[xi], median_calcuated[yi], "sr")

fig.show()
# fig.savefig("gaia17bpi_1028_55_100pts.png", dpi=140)
# Out:
# Quantiles:
# [(0.16, 0.6017969502260835), (0.5, 1.980497302208709), (0.84, 3.3300360425570146)]
# Quantiles:
# [(0.16, 2.699628859512412), (0.5, 2.878616811043184), (0.84, 3.0790815012633144)]
# Quantiles:
# [(0.16, 3.3955534394117723), (0.5, 3.591684751504385), (0.84, 3.7711286255153604)]
# Quantiles:
# [(0.16, 0.7588471825961367), (0.5, 0.985585531243034), (0.84, 1.5024049778811366)]
# C:\Users\tonyc\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ## Plotting after fit

# %%
M_STAR = (10**-0.30)*M_SUN
R_STAR= 0.65*R_SUN
R_OUTER = 15 * R_STAR
M_DOT = (10**-0.62) * 1e-6 * M_SUN / 3.154e7

A_V = 3.

INC = 55.

DIST = 1.27e3*3.08567758128e18
DIREC = 'C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/'

# %%
gaia17bpi_env = FUOriEnvironment(1.5e3, 30.5e3)
gaia17bpi_env.createFUOri(r_star = R_STAR, r_outer = R_OUTER, m_star = M_STAR,\
                          m_dot = M_DOT, inc = INC, a_v = A_V,dist = DIST, grav = 1.5, direc = DIREC, atm_table=ATM_TABLE)
# %time modSpec = gaia17bpi_env.viewModelSpectrum(2.9e3, 28e3, True)
wav, lum = modSpec
# Out:
# Wall time: 22.9 ms

# %%
gaia17bpi_env.fuori.annuli[0].temp
# Out:
# 6000.0

# %%
fig=plt.figure(figsize=(6, 6), dpi= 100)
plt.rcParams.update({'font.size': 14})
plt.plot(np.log10(wav*1e-4), np.log10(lum*wav*1e-8*np.cos(np.radians(INC))/(2*np.pi*DIST**2)), \
         '-', label='Extinction Corrected \nBlackbody Acc. Disk')

plt.errorbar(WAV_DAT, FLUX_DAT, yerr=FLUX_DAT_ERR, marker='o', \
             linestyle='', color='r',label='Palomar + IRTF \nResampled Spectra')

plt.xlabel(r'log $\lambda$ ($\mu$m)')
plt.ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$')
plt.title('Gaia 17bpi SED: Post-MCMC Estimation')
plt.ylim(-16, -10)
plt.xlim(-0.6, 0.5)
plt.legend()
# plt.savefig("sed_gaia17bpi_75.png", dpi=200, bbox_inches='tight')
plt.show()
