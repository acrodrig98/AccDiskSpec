# %% [markdown]
# # Spectra MCMC

# %% [markdown]
# Started 6 December 2019. This uses MCMC to fit model parameters simply based on a snippet of spectrum.

# %% [markdown]
# ### Imports

# %%
import numpy as np
from scipy import optimize
from scipy import interpolate
from scipy import integrate
from astropy.convolution import convolve, convolve_fft
import matplotlib.pyplot as plt
from fu_ori_functions_oct11_copy import *
from fu_ori_classes_oct11_copy import *
import matplotlib.gridspec as gridspec
from PyAstronomy import pyasl
import scipy.signal as signal

import emcee
import corner
import time
# %matplotlib inline
# Out:
# C:\Users\tonyc\AppData\Local\Continuum\anaconda3\lib\site-packages\pyfits\__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
G = 6.67259e-8
SIG_SB = 5.67051e-5
M_SUN = 1.99e33
R_SUN = 6.96e10
L_SUN = 3.839e33
h_PLANCK = 6.6260755e-27
c_LIGHT = 2.99792458e10
k_BOLTZ = 1.380658e-16

# %%
ATM_TABLE = dict()
ATMOS_FACTOR = 100

# %%
def getDataArrayMOD(data_file):
    txt = open(data_file)
    fulltxt = txt.readlines()
    # Cleaning lines
    newtxt = []
    for i in range(0,len(fulltxt), 2):
        line = fulltxt[i][:-1]
        line = line.split()
        if line[0] == '#':
            line = [line[1], line[2]]
        newtxt.append(line)
    # Casting as floats
    newtxt = np.array(newtxt).astype(np.float64)
    return newtxt

# %%
def direcToArray(directory):
    for temp in range(2000, 10000+ATMOS_FACTOR, ATMOS_FACTOR):
        for grav in [1.5, 4.0]:
            try:
                atmos_file = directory + 'pr.lte' + str(int(temp/ATMOS_FACTOR)) \
                        + '-' + str(grav) + '-0.0.spec'
                txt = open(atmos_file)
                fulltxt = txt.readlines()
                # Cleaning lines
                newtxt = []
                for i in range(len(fulltxt)):
                    line = fulltxt[i][:-1]
                    line = line.split()
                    newtxt.append(line)
        
                # Casting as floats
                newtxt = np.array(newtxt).astype(np.float64)
                
                # Choosing which model to use
                wav, lum = newtxt[:,0], newtxt[:,1]
                ATM_TABLE[(temp, grav)] = np.array([wav, lum])
            except:
                print('No atmosphere found for temp = ' + str(temp) + \
                      ' grav = ' + str(grav))

# %%
direcToArray('C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/')
# Out:
# No atmosphere found for temp = 7100 grav = 1.5
# No atmosphere found for temp = 7100 grav = 4.0
# No atmosphere found for temp = 7300 grav = 1.5
# No atmosphere found for temp = 7300 grav = 4.0
# No atmosphere found for temp = 7500 grav = 1.5
# No atmosphere found for temp = 7500 grav = 4.0
# No atmosphere found for temp = 7700 grav = 1.5
# No atmosphere found for temp = 7700 grav = 4.0
# No atmosphere found for temp = 7900 grav = 1.5
# No atmosphere found for temp = 7900 grav = 4.0
# No atmosphere found for temp = 8100 grav = 1.5
# No atmosphere found for temp = 8100 grav = 4.0
# No atmosphere found for temp = 8300 grav = 1.5
# No atmosphere found for temp = 8300 grav = 4.0
# No atmosphere found for temp = 8500 grav = 1.5
# No atmosphere found for temp = 8500 grav = 4.0
# No atmosphere found for temp = 8700 grav = 1.5
# No atmosphere found for temp = 8700 grav = 4.0
# No atmosphere found for temp = 8900 grav = 1.5
# No atmosphere found for temp = 8900 grav = 4.0
# No atmosphere found for temp = 9100 grav = 1.5
# No atmosphere found for temp = 9100 grav = 4.0
# No atmosphere found for temp = 9300 grav = 1.5
# No atmosphere found for temp = 9300 grav = 4.0
# No atmosphere found for temp = 9500 grav = 1.5
# No atmosphere found for temp = 9500 grav = 4.0
# No atmosphere found for temp = 9700 grav = 1.5
# No atmosphere found for temp = 9700 grav = 4.0
# No atmosphere found for temp = 9900 grav = 1.5
# No atmosphere found for temp = 9900 grav = 4.0
# No atmosphere found for temp = 10000 grav = 1.5

# %% [markdown]
# ### Interpolating grid of stellar atmospheres on same grid as data:

# %% [markdown]
# First, reading in data...

# %%
txt_in = getDataArrayMOD('hbc_out_spec_50_55.csv')
WAV_DAT = txt_in[:,0]
FLUX_DAT = txt_in[:,1]
FLUX_DAT_ERR = 0.2*FLUX_DAT

# %%
WAV_DAT_CLIP = WAV_DAT[1:-1]
FLUX_DAT_CLIP = FLUX_DAT[1:-1]
FLUX_DAT_ERR_CLIP = FLUX_DAT_ERR[1:-1]

# %%
import spectres

# %%
def getInterpTable(st_atm_table, waves_data):
    out_table = dict()
    for key in ATM_TABLE:
        wav, lum = ATM_TABLE[key]
#         interp_func = interpolate.interp1d(wav, lum, kind = 'linear')
#         out_table[key] = waves_data, interp_func(waves_data)
        out_table[key] =  waves_data, spectres.spectres(waves_data, wav, lum)
    return out_table

# %%
ATM_TABLE_INTERP = getInterpTable(ATM_TABLE, WAV_DAT)

# %%
ATM_TABLE_INTERP.keys()
# Out:
# dict_keys([(2000, 1.5), (2000, 4.0), (2100, 1.5), (2100, 4.0), (2200, 1.5), (2200, 4.0), (2300, 1.5), (2300, 4.0), (2400, 1.5), (2400, 4.0), (2500, 1.5), (2500, 4.0), (2600, 1.5), (2600, 4.0), (2700, 1.5), (2700, 4.0), (2800, 1.5), (2800, 4.0), (2900, 1.5), (2900, 4.0), (3000, 1.5), (3000, 4.0), (3100, 1.5), (3100, 4.0), (3200, 1.5), (3200, 4.0), (3300, 1.5), (3300, 4.0), (3400, 1.5), (3400, 4.0), (3500, 1.5), (3500, 4.0), (3600, 1.5), (3600, 4.0), (3700, 1.5), (3700, 4.0), (3800, 1.5), (3800, 4.0), (3900, 1.5), (3900, 4.0), (4000, 1.5), (4000, 4.0), (4100, 1.5), (4100, 4.0), (4200, 1.5), (4200, 4.0), (4300, 1.5), (4300, 4.0), (4400, 1.5), (4400, 4.0), (4500, 1.5), (4500, 4.0), (4600, 1.5), (4600, 4.0), (4700, 1.5), (4700, 4.0), (4800, 1.5), (4800, 4.0), (4900, 1.5), (4900, 4.0), (5000, 1.5), (5000, 4.0), (5100, 1.5), (5100, 4.0), (5200, 1.5), (5200, 4.0), (5300, 1.5), (5300, 4.0), (5400, 1.5), (5400, 4.0), (5500, 1.5), (5500, 4.0), (5600, 1.5), (5600, 4.0), (5700, 1.5), (5700, 4.0), (5800, 1.5), (5800, 4.0), (5900, 1.5), (5900, 4.0), (6000, 1.5), (6000, 4.0), (6100, 1.5), (6100, 4.0), (6200, 1.5), (6200, 4.0), (6300, 1.5), (6300, 4.0), (6400, 1.5), (6400, 4.0), (6500, 1.5), (6500, 4.0), (6600, 1.5), (6600, 4.0), (6700, 1.5), (6700, 4.0), (6800, 1.5), (6800, 4.0), (6900, 1.5), (6900, 4.0), (7000, 1.5), (7000, 4.0), (7200, 1.5), (7200, 4.0), (7400, 1.5), (7400, 4.0), (7600, 1.5), (7600, 4.0), (7800, 1.5), (7800, 4.0), (8000, 1.5), (8000, 4.0), (8200, 1.5), (8200, 4.0), (8400, 1.5), (8400, 4.0), (8600, 1.5), (8600, 4.0), (8800, 1.5), (8800, 4.0), (9000, 1.5), (9000, 4.0), (9200, 1.5), (9200, 4.0), (9400, 1.5), (9400, 4.0), (9600, 1.5), (9600, 4.0), (9800, 1.5), (9800, 4.0), (10000, 4.0)])

# %%
class FUOriEnvironment:
    
    # Initializer / Instance Attributes
    def __init__(self, wave_lower_spec, wave_upper_spec, wave_lower_SED, wave_upper_SED):
        
        self.wave_lower_spec = wave_lower_spec
        self.wave_upper_spec = wave_upper_spec
        self.wave_lower_SED = wave_lower_SED
        self.wave_upper_SED = wave_upper_SED
        
        # Storing classes
        self.fuori = []
                
    # instance methods
    
    # Creating FU Ori object as accretion disk
    def createFUOri(self, r_star, r_outer, m_star, m_dot, inc, a_v, dist, grav, direc, atm_table):
        fuori = FUOri(r_star, r_star, r_outer, m_star, m_dot, np.radians(inc), a_v, atm_table)
        fuori.setAnnuliValues(10000, 2000, 200, 1*r_star)
#         fuori.r_a, fuori.r_b, fuori.temps = makeMod(fuori.r_a, fuori.r_b, fuori.temps, bins=50)
        fuori.createAnnuliFromDirec(grav, direc, model='stellar atmospheres')
        fuori.prepareAnnuli(self.wave_lower_spec,self.wave_upper_spec, \
                            broaden=True, interp_type='linear')
        fuori.createModelSpectrum('stellar atmospheres', broaden=True)
        self.fuori.append(fuori)
        
    # For viewing model spectrum
    def viewModelSpectrum(self, wave_lower, wave_upper, obj_type, obj_num, broaden, redden):
        if obj_type == 'fu ori':
            return self.fuori[obj_num].viewModelSpectrum(wave_lower, wave_upper, broaden, redden)
        elif obj_type == 'rotating star':
            return self.rot_star.getLuminosity(wave_lower, wave_upper, broaden, redden)

# %% [markdown]
# ### Making an instance of the class

# %%
[0.58124186, 1.81556243, 0.68216858, 0.46893486]
# Out:
# [0.58124186, 1.81556243, 0.68216858, 0.46893486]

# %%
M_STAR = 0.581*M_SUN
R_STAR= 1.816*R_SUN
R_OUTER = 50 * R_SUN
M_DOT = (10**0.682) * 1e-6 * M_SUN / 3.154e7

A_V = 2.75
INC = np.degrees(np.arccos(0.4689))
DIST = 795*3.08567758128e18
DIREC = 'C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/'

# %%
np.degrees(np.arccos(0.44))
# Out:
# 63.8961188626601

# %%
# %time gaia17bpi_env = FUOriEnvironment(4.95e3, 5.55e3, 0, 0)
# Spectrum fit
# %time gaia17bpi_env.createFUOri(r_star = R_STAR, r_outer = R_OUTER, m_star =  M_STAR,\
                          m_dot = M_DOT, \
                                inc = INC, a_v = 2.75,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)
# # SED fits
# %time gaia17bpi_env.createFUOri(r_star = 1.84*R_SUN, r_outer = R_OUTER, m_star = 1.59*M_SUN,\
                          m_dot = (10**0.17) * 1e-6 * M_SUN / 3.154e7, inc = 30, a_v = 2.74,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)
# %time gaia17bpi_env.createFUOri(r_star = 2.47*R_SUN, r_outer = R_OUTER, m_star = 2.19*M_SUN,\
                          m_dot = (10**0.44) * 1e-6 * M_SUN / 3.154e7, inc = 60, a_v = 2.73,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)
# %time gaia17bpi_env.createFUOri(r_star = 2.44*R_SUN, r_outer = R_OUTER, m_star = 2.85*M_SUN,\
                          m_dot = (10**0.27) * 1e-6 * M_SUN / 3.154e7, inc = 60, a_v = 2.73,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)


# Spectrum fit 2
# %time gaia17bpi_env.createFUOri(r_star = 0.99*R_SUN, r_outer = R_OUTER, m_star =  1.05*M_SUN,\
                          m_dot = (10**0.23) * 1e-6 * M_SUN / 3.154e7, \
                                inc = np.degrees(np.arccos( 0.44)), a_v = 2.75,dist = DIST, grav = 1.5, \
                                direc = DIREC, atm_table=ATM_TABLE_INTERP)
# Out:
# Wall time: 0 ns
# Wall time: 102 ms
# Wall time: 81.8 ms
# Wall time: 78.8 ms
# Wall time: 71.9 ms
# Wall time: 118 ms

# %%
gaia17bpi_env.fuori[0].annuli[0].temp, gaia17bpi_env.fuori[1].annuli[0].temp, \
gaia17bpi_env.fuori[2].annuli[0].temp, gaia17bpi_env.fuori[3].annuli[0].temp, gaia17bpi_env.fuori[4].annuli[0].temp
# Out:
# (6000.0, 5800.0, 5800.0, 5800.0, 8600.0)

# %%
START = 5000
END = 5500

# %%
wav, lum = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 0, True, False)
flux  = pyasl.unred(wav, lum*np.cos(gaia17bpi_env.fuori[0].inc)/(2*np.pi*DIST**2), -gaia17bpi_env.fuori[0].a_v/3.1)

# %%
wav2, lum2 = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 1, True, False)
flux2  = pyasl.unred(wav2, lum2*np.cos(np.radians(30))/(2*np.pi*DIST**2), -gaia17bpi_env.fuori[1].a_v/3.1)

# %%
wav3, lum3 = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 2, True, False)
flux3  = pyasl.unred(wav3,lum3*np.cos(np.radians(60))/(2*np.pi*DIST**2), -gaia17bpi_env.fuori[2].a_v/3.1)

# %%
wav4, lum4 = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 3, True, False)
flux4  = pyasl.unred(wav4, lum4*np.cos(np.radians(60))/(2*np.pi*DIST**2), -gaia17bpi_env.fuori[3].a_v/3.1)

# %%
wav5, lum5 = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 4, True, False)
flux5  = pyasl.unred(wav5, lum5*np.cos(gaia17bpi_env.fuori[4].inc)/(2*np.pi*DIST**2), -gaia17bpi_env.fuori[4].a_v/3.1)

# %% [markdown]
# ### Plotting data with model

# %%
def chiSquareSum(data, model):
    return np.sum((data - model)**2/model**2)

# %%
chiSquareSum(FLUX_DAT_CLIP[10:-10], 1e-8*flux[10:-10]),\
chiSquareSum(FLUX_DAT_CLIP[10:-10], 1e-8*flux2[10:-10]),\
chiSquareSum(FLUX_DAT_CLIP[10:-10], 1e-8*flux3[10:-10]),\
chiSquareSum(FLUX_DAT_CLIP[10:-10], 1e-8*flux4[10:-10])
# Out:
# (115.98598871213997, 18.641174458023414, 9.425137264425848, 9.729167018716089)

# %%
b, a = signal.butter(1, 0.005, 'low', analog=False)
filtered_data = signal.filtfilt(b, a,   FLUX_DAT_CLIP[10:-10])
b, a = signal.butter(1, 0.005, 'low', analog=False)
filtered_model = signal.filtfilt(b, a,   1e-8*flux[10:-10])

data_new =  FLUX_DAT_CLIP[10:-10]/filtered_data
model_new = 1e-8*flux[10:-10]/filtered_model

# %%
fig=plt.figure(figsize=(10, 5), dpi= 200)
gs = gridspec.GridSpec(2, 1,height_ratios=[3, 1])
plt.rcParams.update({'font.size': 14})

ax = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])

# ax.plot(WAV_DAT_CLIP[10:-10], FLUX_DAT_CLIP[10:-10], 'r-', markersize=1, alpha=1, label='Data')
# ax.plot(wav[10:-10],1e-8*flux[10:-10], 'b-', markersize = 1,  label='Spectrum fit')

ax.plot(WAV_DAT_CLIP[10:-10], data_new,  'r-', markersize=1, alpha=1, label='Data')
ax.plot(wav[10:-10], model_new, 'b-', markersize = 1,  label='Spectrum fit')




# ax2.plot(wav[10:-10], 100*(FLUX_DAT_CLIP[10:-10]-1e-8*flux[10:-10]  )/(1e-8*flux[10:-10]), '-', markersize=1)
ax2.plot(wav[10:-10], 100*(data_new - model_new)/(model_new), '-', markersize=1)

ax2.plot(wav, np.zeros(len(flux)), 'k--')


ax2.set_xlabel(r'$\lambda$ (Angstroms)')
ax.set_ylabel(r'$F_\lambda (erg\quad s^{-1} cm^{-2} \AA^{-1})$')
ax2.set_ylabel(r'Percent Difference')

ax.set_title('HBC 722 Spectrum: Post-MCMC Fit')
# ax.set_xlim(5002, 5449)
# ax2.set_xlim(5002, 5449)


ax.legend()
# plt.savefig("sed_gaia17bpi_75.png", dpi=200, bbox_inches='tight')
plt.show()

# %%
def getLstSqrs(theta):
    
    m_star, r_star, m_dot, inc = theta
    
    r_star = r_star*R_SUN
    m_dot = 10**m_dot
    m_star = m_star*M_SUN
    inc = np.degrees(np.arccos(inc))
    
    m_dot = m_dot* 1e-6 * M_SUN / 3.154e7
    try:
    
        gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3,0,0)
        gaia17bpi_env.createFUOri(r_star = r_star, r_outer = R_OUTER, m_star = m_star,\
                              m_dot = m_dot, inc = inc, a_v = A_V, dist = DIST, grav = 1.5, \
                                  direc = DIREC, atm_table=ATM_TABLE_INTERP)
    
    # Accounts for any random case where the model may not be generated properly given a certain combination
    # of parameters. This has only happened once, but it's presumably when the maximum temperature is too low.
    except:
        return 0
    
    # Converting units to properly compare model to data
    wav, lum = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 0, True, False)
    model = pyasl.unred(wav, 1e-8*lum*np.cos(np.radians(inc))/(2*np.pi*DIST**2), -A_V/3.1)[10:-10]

    data = FLUX_DAT_CLIP[10:-10]

    return 1e28*np.sum((model - data)**2)

# %%
getLstSqrs([0.6, 1.66,0.66, 0.54])
# Out:
# 3.6798027016403707

# %%
from scipy import optimize
x0 = [0.6, 1.66, 0.66, 0.54]
# %time optimize.minimize(getLstSqrs, x0, method='Nelder-Mead', tol=1e-6)
# Out:
# Wall time: 41.9 s
#  final_simplex: (array([[0.59169726, 1.63334166, 0.64699331, 0.55921543],
#        [0.59169728, 1.63334232, 0.64699383, 0.5592151 ],
#        [0.59169723, 1.63334152, 0.64699323, 0.5592154 ],
#        [0.59169717, 1.63334084, 0.64699273, 0.55921559],
#        [0.59169724, 1.63334145, 0.64699317, 0.55921548]]), array([3.6323765, 3.6323765, 3.6323765, 3.6323765, 3.6323765]))
#            fun: 3.6323765009086677
#        message: 'Optimization terminated successfully.'
#           nfev: 596
#            nit: 341
#         status: 0
#        success: True
#              x: array([0.59169726, 1.63334166, 0.64699331, 0.55921543])

# %% [markdown]
# ## MCMC Routine

# %%
def lnlike(theta, x, y, yerr):
    m_star, r_star, m_dot, inc = theta
    
    r_star = r_star*R_SUN
    m_dot = 10**m_dot
    m_star = m_star*M_SUN
    inc = np.degrees(np.arccos(inc))
    
    m_dot = m_dot* 1e-6 * M_SUN / 3.154e7
    try:
    
        gaia17bpi_env = FUOriEnvironment(3.0e3, 28.5e3,0,0)
        gaia17bpi_env.createFUOri(r_star = r_star, r_outer = R_OUTER, m_star = m_star,\
                              m_dot = m_dot, inc = inc, a_v = A_V, dist = DIST, grav = 1.5, \
                                  direc = DIREC, atm_table=ATM_TABLE_INTERP)
    
    # Accounts for any random case where the model may not be generated properly given a certain combination
    # of parameters. This has only happened once, but it's presumably when the maximum temperature is too low.
    except:
        return 0
    
    # Converting units to properly compare model to data
    wav, lum = gaia17bpi_env.viewModelSpectrum(START, END, 'fu ori', 0, True, False)
    model = pyasl.unred(wav, 1e-8*lum*np.cos(np.radians(inc))/(2*np.pi*DIST**2), -A_V/3.1)[10:-10]
    
    # Dividing by low-pass filter to normalize
    b, a = signal.butter(1, 0.005, 'low', analog=False)
    model = model/signal.filtfilt(b, a, model)

    inv_sig = 1/yerr
    return np.sum(np.log((1/np.sqrt(2*np.pi))*inv_sig) - 0.5*((y - model)*inv_sig)**2)

# %%
M_STAR_LOW = 0.2
M_STAR_HIGH = 1.0

R_STAR_LOW = 0.3
R_STAR_HIGH = 4.0

M_DOT_LOW = -1.5
M_DOT_HIGH = 2.5

INC_LOW = np.cos(np.radians(89))
INC_HIGH = np.cos(np.radians(1))

# %%
def lnprior(theta):
    m_star, r_star, m_dot, inc= theta
    if M_DOT_LOW  < m_dot < M_DOT_HIGH \
    and M_STAR_LOW < m_star < M_STAR_HIGH\
    and R_STAR_LOW < r_star < R_STAR_HIGH\
    and INC_LOW < inc < INC_HIGH:
        return 0.0
    return -np.inf

# %%
def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return (lp + lnlike(theta, x, y, yerr))

# %%
ndim, nwalkers = 4, 12
m_star_start = 0.58
r_star_start = 1.8
m_dot_start = 0.68
inc_start = 0.468
start = np.array((m_star_start, r_star_start, m_dot_start, inc_start))
pos = [start + 1e-3*np.random.randn(ndim) for i in range(nwalkers)]

# %%
plt.errorbar(x, y_meas, )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
b, a = signal.butter(1, 0.005, 'low', analog=False)
filtered_data = signal.filtfilt(b, a,   FLUX_DAT_CLIP)

# %%
x = WAV_DAT_CLIP
y_meas = FLUX_DAT_CLIP/filtered_data
y_err = y_meas/10

# %%
lnprob((m_star_start, r_star_start, m_dot_start, inc_start), x[10:-10],y_meas[10:-10],y_err[10:-10])
# Out:
# 193.42990753418962

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x[10:-10], y_meas[10:-10], y_err[10:-10]))
# %time sampler.run_mcmc(pos, 2000, progress=True)
# Out:
# C:\Users\tonyc\AppData\Local\Continuum\anaconda3\lib\site-packages\emcee\ensemble.py:258: RuntimeWarning: Initial state is not linearly independent and it will not allow a full exploration of parameter space
#   category=RuntimeWarning,
# 100%|██████████████████████████████████████████████████████████████████████████████| 2000/2000 [41:14<00:00,  1.45s/it]
# Wall time: 41min 15s
# State([[ 0.70683081  0.78758081  0.27906388  0.04124067]
#  [ 0.91955958  0.36776025 -0.76754066  0.83205885]
#  [ 0.469042    0.38840158 -0.45586266  0.44206778]
#  [ 0.42779764  0.33092996 -0.57169563  0.43460029]
#  [ 0.69691452  0.64222322  0.0635114   0.26631747]
#  [ 0.92840206  0.48836118 -0.39158123  0.24630795]
#  [ 0.66983225  0.40622105 -0.59941049  0.6347108 ]
#  [ 0.96006211  0.70625417  0.03026825  0.43172843]
#  [ 0.89321922  0.86588936  0.34424676  0.10044911]
#  [ 0.86140548  0.89322557  0.39892515  0.23579848]
#  [ 0.98725188  0.77794082  0.15625005  0.27619478]
#  [ 0.93822347  0.42120865 -0.61777258  0.53190323]], log_prob=[435.79300691 435.47991945 435.04485134 438.09375559 436.8444372
#  438.70907871 434.42774477 436.90018947 437.25065898 436.98030121
#  437.02745823 437.20169147], blobs=None, random_state=('MT19937', array([3264856268, 1023666519,  604755534, 1084556951, 2155044599,
#         319078884, 4160404903, 2876962675, 1019667981, 3584708431,
#         156524213, 3375743890, 2675625639, 1043071021, 3454380899,
#        2766426074, 3649462682, 3799798269, 1895168766, 3531387228,
#        2737990609, 1102970216, 3146339734, 3323033252,  946033621,
#        3316167694, 2195900781, 1574471723, 1075135299, 1658816577,
#        2416703191, 1375876803, 3945742260, 4221652111, 2446674849,
#        1552560531, 1701756157, 2759010782, 1259414066, 3682148214,
#        2387909911, 2790728189, 2947257657, 1691814743,  346890872,
#        1252258451, 4234507539, 4001631403, 3182388854, 1852179512,
#        3266907593, 1148673519, 4130308243, 2371523978, 3519931490,
#         285378484, 2543717551, 3277749949, 3031031802, 2990127936,
#        3681874324, 3193754343, 4022384417, 1987702341, 1864043522,
#         646815794,   28259620, 1187596076, 3173357793, 1427907205,
#        1712056489,  815443221, 3138369402, 1255302330, 3628824974,
#         101849715, 2903882946,  718456370, 3759486239, 4224261165,
#        2325899430, 3973377671,  851314783, 4050252283, 1906924351,
#        3747196216,  151756403, 2609443254, 3113253857, 3152577907,
#         895217663, 2841569781, 2886159063, 4067536297,  584707538,
#        1152160864, 2653253510, 1338457801, 2040811657, 4103213787,
#         560815420, 4241989552,  577765936, 3949406633, 1557766045,
#        2494374047, 2446503019, 3925100315, 3165403583,  105431147,
#         857690602, 4129706938, 3916075335,  376377391, 1506046130,
#        2392201192, 1689978230, 2192135365, 2726608661, 3073767239,
#        1232469441,  284089876, 1060663592, 2333288700, 4227488117,
#         112033114, 1452765892, 1813308183, 4154836616, 1526202902,
#         529130250, 1827129017, 1256470072, 2521347182,  213154256,
#        3624444715,  409492218,  759663620, 1256641983, 2545291889,
#        4011565313,  719214420, 2506402138, 3584866247, 2000724227,
#        2698077159,  248549987,  338164329, 2619059603,  248700032,
#        3686514640, 1457271345, 1043784251, 2902931153,  479687448,
#        1789702955, 3412798041, 1938270048, 2437814382, 2101154796,
#        1168474977,  651313725, 2544983828, 1610041816, 3055681354,
#        4208024479,  671071513, 1839681922, 3074754161, 1292807265,
#        2405844998, 2168866945,    7359888, 2832911784, 4224770809,
#         741211771, 3953828376, 2122496392, 1534075684, 2331353432,
#        3236255319,  943245308, 1475215435, 3106870784, 1785742963,
#         232750271,   30055618,    3896147, 3035362806,  362943911,
#        1371732327, 2989471770, 4272132319, 1918197256,  744344746,
#        2333561798, 1373925853, 1721281200, 2251209207, 1357583842,
#        2186672110, 2727792959, 4119765853,  645425011, 1707397441,
#        1132420387, 1024031477, 2142630845, 1487934153, 3646547675,
#         695761320, 1852413122, 2877999063,  960571144, 2900783108,
#        3054346573,  448702957, 3500439335,  169323095, 1861501411,
#        3419822007,  915155642, 1725854987, 2234724619,  947108618,
#        2810739326, 4182236964, 3650141667, 2599637504, 2059782102,
#         683695238, 2806103774, 2449970324,  821273331, 3862895515,
#        2575739567, 3653009918, 2664958998, 1932918059, 1769602735,
#         741169829, 2203639011,  585514477, 2908602420, 3120340070,
#        3083508502,  498937955, 4184301090, 1891541391,  323831685,
#         660557072, 3227387735, 1632117139, 3787839782,  720158981,
#        1636325291, 1023141201,  337142894,  413469179, 2548887808,
#         559114721, 3458162292, 3924651016, 4128942040, 3123793169,
#        1819175152, 3712122662, 2716694584, 2590376851, 2518698509,
#        4271712106, 1589331305, 3882043908, 3501794570, 4198439585,
#        3708638142, 3144662170, 3514033692,  335111796, 3941067105,
#        2848242268, 2950131902, 3251312877, 3309983352, 1047974983,
#        3121310411, 2214368510, 3254120644, 1651499606, 3729033430,
#        3599588216, 2988153401, 1166694243,  852233918, 3866891291,
#        4288014858, 2255456071,   40544631, 2004130943, 1875122636,
#         498565343, 4080539813, 2951582609, 1290288668, 4246623514,
#        1135824338,  759817292, 4081378301,  187814692, 1378283209,
#        2657459047, 2420097143, 2995257959, 2926806799, 3320194073,
#        3157809600, 1064186437, 2067690164, 3285257280,  222510207,
#        1565142576, 3643214015, 1891322360, 1283602810, 2778211246,
#        2567417517, 3720261082,  943187548, 2651763165, 1820981864,
#        2214537250, 3369395984, 2101450576, 1143309828, 3062335597,
#        2556882549, 3548305953, 1566556157, 3971997291, 2208435865,
#        2497612178,  480313481, 1348208436, 1011497662,  439326805,
#          54193546,  638875550, 3209904818, 2730365838, 3115202109,
#        4130767560,  876377857, 3188703968, 3314326563,  198744827,
#         108292702, 1622155669,  943607179, 2780123511,   19491233,
#        3633388741, 1899153612, 3941280071, 4294227960, 1391761139,
#        4180256097,  473106291, 3137940846, 2017225943, 1221122402,
#        3920013696, 3255147949,  229919764, 1148553077, 4105512213,
#        2562405880,  280068169, 1511744153,  786752039,  803731199,
#          46305544, 3304537685, 3188213706, 3830523607, 2605555815,
#        1244483928, 3871555987, 2841080069, 1806370350,  147880961,
#        3161093974,  340338854, 1445062642, 2879484021, 3631852635,
#        2569238771,  489382386, 2283887513, 1246297286,  280896589,
#        3796422359,  498344779, 2277862442, 3063992458, 1299318765,
#        4053697939, 3433392046,  745549778, 1683206814,  850890819,
#        2655991373, 3250334250, 4122253933, 3886225826, 2560060643,
#        1862008255,  203976435,  614884433, 2629550952, 1127979760,
#         371374420,  554499350,  214335058, 4240089261, 4071297978,
#         933106058, 2284691650,  796653895,  877488843, 2628154423,
#        2664047354, 4288548464, 2860149463,  582670218, 3428890097,
#        2210704780,  709690300,  717836809, 1694260026, 3217841806,
#         747074104,  150155323, 3388127011, 3039731222,  448844276,
#        1270958300, 3478187721, 2873089282, 1188842935,  793714634,
#          65680870, 3070009681, 2562764574, 3999720721, 3042338133,
#        3322204067, 4027133619, 4191071380, 1673488551, 4256290781,
#        2975959082, 3181150583, 1606553122, 2388978473, 2282753825,
#        2616302415, 1793900367, 2575236287,  646505921,  647583766,
#        3412880073, 1616939426, 2244586693,  757966319, 2000771858,
#        1425425976, 4230984500, 3456796945, 2064629554, 2455509291,
#        3244909439, 2082668703, 3957721955, 2890073647, 3689421708,
#        3872647767, 4195067954, 3814506942, 3825430114,  573215807,
#        2439077010, 3361643432, 4199826567,  616883457, 2277493588,
#        4251454285, 3428500856, 2352459097, 3599840562,  533405309,
#        1038979398, 1168788811, 1930362203,   14814090,  165004417,
#         872206108,  748929973, 2303099327, 1506845063, 2674286208,
#        3233934363, 3767680194,  393157108,  458964070, 1270959306,
#        3028061375, 2203209934, 1947798729, 1496386078,  916005503,
#        3159658076, 2925368384,  729058375, 1235910197,  336777588,
#         327888533,  220504566, 3716206191, 3943426384, 1952989061,
#        2543722350, 1006282338, 2776939373,  182111527, 1615909178,
#        2152091446,  172591004, 3039287377, 3133142919, 1344689827,
#        3580048228, 1820937982, 3185467850, 2462807430, 3619207761,
#        1528446253, 3243921802, 4021402383, 2067947380, 1805615507,
#        2103232000, 2594683637, 1151148343, 2132708089, 3250732354,
#        3471782504, 1977169841,  390595841,  924603561, 1177991144,
#         554388692, 1723001412, 1797216289, 2087715379,  360323882,
#         946334956,  645353207, 3483654145, 2842070639, 2553478327,
#        3051287764, 1871571548,  382810745, 3122084563, 3662021603,
#        3225054742, 1398066391, 3116484524, 2795644202, 4255499549,
#         291679105, 2337789916, 2791146018,  859497055, 1500140387,
#        1264805526, 3403312917, 2309813483, 1340400130, 4234049596,
#        2524823000, 3801979830,  447254160, 2678754976, 1190854038,
#        3137508646, 1093899772, 1342485874,  793228477,  281953889,
#        1597884212, 1131751773, 2760946090, 3010892290, 2221559124,
#        2638214932,  695113439,  503736533, 2290230686, 2434206829,
#        1384679095,  892858949, 1562707426, 3690114152, 3017658228,
#        3602226385, 2871793938, 1448600433, 3802754902, 4146469334,
#         178762968, 4166359063, 1769275470, 1013416340], dtype=uint32), 444, 0, 0.0))

# %%
samples = sampler.chain[:, 1000:, :].reshape((-1, ndim))
fig = plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 16})

plt.plot(samples)
plt.xlabel('Step number')
plt.ylabel('Estimated values of parameters')
plt.title('Evolution in estimated values using MCMC')
plt.xticks([])
plt.show()

# %%
median_calcuated = np.median(samples, axis=0)

fig = corner.corner(samples, labels=[r'$M_*$', r'$ R_*$',r'$\log\;\dot{M}$', 'inc'], verbose=True,
                       quantiles=(0.16, 0.5,0.84), plot_contours=True, scale_hist=True,
                       show_titles=True, title_kwargs={"fontsize": 12})

axes = np.array(fig.axes).reshape((ndim, ndim))

for i in range(ndim):
    ax = axes[i, i]
    ax.axvline(median_calcuated[i], color="r")
    
for yi in range(ndim):
    for xi in range(yi):
        ax = axes[yi, xi]
        ax.axvline(median_calcuated[xi], color="r")
        ax.axhline(median_calcuated[yi], color="r")
        ax.plot(median_calcuated[xi], median_calcuated[yi], "sr")

fig.show()
# fig.savefig("gaia17bpi_1028_55_100pts.png", dpi=140)
# Out:
# Quantiles:
# [(0.16, 0.6703507792990578), (0.5, 0.8407654707795126), (0.84, 0.9700144431245792)]
# Quantiles:
# [(0.16, 0.39636356100046033), (0.5, 0.5517338190620189), (0.84, 0.82574014087243)]
# Quantiles:
# [(0.16, -0.609105802563762), (0.5, -0.1917104660291799), (0.84, 0.293823771216524)]
# Quantiles:
# [(0.16, 0.09417873959356807), (0.5, 0.27047584422978765), (0.84, 0.5029788750938147)]
# C:\Users\tonyc\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ## Plotting after fit

# %%
M_STAR = (10**-0.30)*M_SUN
R_STAR= 0.65*R_SUN
R_OUTER = 15 * R_STAR
M_DOT = (10**-0.62) * 1e-6 * M_SUN / 3.154e7

A_V = 3.

INC = 55.

DIST = 1.27e3*3.08567758128e18
DIREC = 'C:/Users/tonyc/OneDrive/Documents/2019 Summer/Stellar Atmospheres/'

# %%
gaia17bpi_env = FUOriEnvironment(1.5e3, 30.5e3)
gaia17bpi_env.createFUOri(r_star = R_STAR, r_outer = R_OUTER, m_star = M_STAR,\
                          m_dot = M_DOT, inc = INC, a_v = A_V,dist = DIST, grav = 1.5, direc = DIREC, atm_table=ATM_TABLE)
# %time modSpec = gaia17bpi_env.viewModelSpectrum(2.9e3, 28e3, True)
wav, lum = modSpec
# Out:
# Wall time: 22.9 ms

# %%
gaia17bpi_env.fuori.annuli[0].temp
# Out:
# 6000.0

# %%
fig=plt.figure(figsize=(6, 6), dpi= 100)
plt.rcParams.update({'font.size': 14})
plt.plot(np.log10(wav*1e-4), np.log10(lum*wav*1e-8*np.cos(np.radians(INC))/(2*np.pi*DIST**2)), \
         '-', label='Extinction Corrected \nBlackbody Acc. Disk')

plt.errorbar(WAV_DAT, FLUX_DAT, yerr=FLUX_DAT_ERR, marker='o', \
             linestyle='', color='r',label='Palomar + IRTF \nResampled Spectra')

plt.xlabel(r'log $\lambda$ ($\mu$m)')
plt.ylabel(r'log $\lambda F_\lambda (erg\quad s^{-1} cm^{-2})$')
plt.title('Gaia 17bpi SED: Post-MCMC Estimation')
plt.ylim(-16, -10)
plt.xlim(-0.6, 0.5)
plt.legend()
# plt.savefig("sed_gaia17bpi_75.png", dpi=200, bbox_inches='tight')
plt.show()
